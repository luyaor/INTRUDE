# %%
from gen import *

with open('data/small_part_negative.txt', 'w+') as f:
    for i in range(1800):
        if i % 100 == 0:
            print(i)
        print(' '.join(random_pairs()), file=f)

# %%
o = open('tmp/bow2.txt', 'w')

a = {}

from main import *
with open('data/msr_positive_pairs.txt') as f:
    for t in f.readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        b1 = get_BoW(p1["title"])
        b2 = get_BoW(p2["title"])
        #b1 = list(set(b1))
        #b2 = list(set(b2))
        z = set(b1) & set(b2)
        for t in z:
            if t not in a:
                a[t] = 0
            a[t] += 1
        
        z = list(filter(lambda x: len(x) >= 2, list(z)))
        print(z, file=o)
        # print(len(set(b1) & set(b2)), 1, file=o)
        #print(set_similarity(b1, b2), 2, file=o)

'''
t = sorted(a.items(), key=lambda x: x[1], reverse=True)
for x in t:
    if len(x[0]) >= 2:
        print(x)
'''

# %%
# filter msr
g = open('data/small_part_msr.txt', 'w+')
with open('data/msr_positive_pairs.txt') as f:
    for l in f.readlines():
        r, n1, n2 = l.split()
        # if r in ['scikit-learn/scikit-learn', 'nodejs/node', 'dotnet/corefx']:
        if r in ['angular/angular.js', 'mozilla-b2g/gaia', 'kubernetes/kubernetes']:
            print(r, n1, n2, file=g)
g.close()

# %%
import os

repos = os.listdir('/DATA/luyao/pr_data')

li = []
for repo in repos:
    t = os.listdir('/DATA/luyao/pr_data/' + repo)
    for v in t:
        li.append(repo + '/' + v)

# print('\n'.join(li))

for t in li:
    t = t.strip()    
    pr = os.listdir('/DATA/luyao/pr_data/%s' % t)
    print(t, len(pr))       

'''
with open('data/msr_repo_list.txt') as f:
    for t in f.readlines():
        t = t.strip()    
        pr = os.listdir('/DATA/luyao/pr_data/%s' % t)
        print(t, len(pr))
'''
# Out:
# zendframework/zendframework 5633
# zendframework/zf2 4255
# zendframework/ZendSkeletonApplication 302
# blueimp/jQuery-File-Upload 331
# almasaeed2010/AdminLTE 366
# ftlabs/fastclick 1
# ga-students/wdi-fundamentals-rps 1
# vinta/awesome-python 1
# wasabeef/awesome-android-ui 148
# nostra13/Android-Universal-Image-Loader 142
# hakimel/reveal.js 692
# open-source-society/computer-science 3
# jlord/patchwork 8649
# FortAwesome/Font-Awesome 3
# jashkenas/backbone 1831
# saltstack/salt 29661
# appium/appium 1
# NetEase/pomelo 163
# torvalds/linux 1
# airbnb/lottie-android 39
# airbnb/javascript 4
# sympy/sympy 1
# janl/mustache.js 292
# designmodo/Flat-UI 73
# learnstreet-dev/learnstreet 4
# HubPress/hubpress.io 177
# apache/hadoop 379
# apache/incubator-dubbo 83
# apache/spark 10
# emberjs/ember.js 7557
# cloudfoundry/java-buildpack 206
# dodgepudding/wechat-php-sdk 144
# pydata/pandas 9100
# robbyrussell/oh-my-zsh 1
# DefinitelyTyped/DefinitelyTyped 5
# jfeinstein10/SlidingMenu 131
# mrdoob/three.js 6320
# nightscout/cgm-remote-monitor 1
# numpy/numpy 1
# nodejs/node 12830
# nodejs/node-v0.x-archive 3799
# caolan/async 613
# tensorflow/tensorflow 8291
# coreos/etcd 1
# TheOdinProject/curriculum 1
# twbs/bootstrap 8963
# pixijs/pixi.js 1
# ansible/ansible 24198
# SignalR/SignalR 917
# elastic/elasticsearch 15365
# MarlinFirmware/Marlin 4
# Homebrew/homebrew-core 4
# Homebrew/homebrew-cask 2
# Homebrew/homebrew 3
# Homebrew/legacy-homebrew 3
# Poole/hyde 135
# Poole/lanyon 121
# laravel/laravel 3009
# laravel/framework 13791
# ionic-team/ionic 110
# alibaba/dubbo 535
# socketio/socket.io 714
# jquery/jquery 1
# jquery/jquery-ui 1858
# dotnet/corefx 17665
# bumptech/glide 1
# spring-projects/spring-framework 1878
# spring-projects/spring-boot 10
# django/django 10179
# nathanmarz/storm 306
# peachananr/onepage-scroll 3
# CocoaPods/Specs 1
# octocat/Spoon-Knife 14971
# OpenCV/opencv 1
# opencv/opencv 4
# gohugoio/hugo 89
# rails/rails 21418
# rdpeng/ExData_Plotting1 763
# rdpeng/RepData_PeerAssessment1 374
# chrisbanes/PhotoView 124
# Bower/bower 636
# bower/bower 59
# PokemonGoMap/PokemonGo-Map 1
# npm/npm 2131
# rust-lang/rust 17751
# udacity/fullstack-nanodegree-vm 67
# udacity/frontend-nanodegree-resume 305
# udacity/ud851-Exercises 1
# driftyco/ionic 2097
# ceph/ceph 23064
# WordPress/WordPress 352
# mmistakes/minimal-mistakes 959
# Trinea/android-open-project 1
# ArduPilot/ardupilot 5432
# thomasdavis/backbonetutorials 5
# twitter/bootstrap 8827
# jwasham/coding-interview-university 2
# jwasham/google-interview-university 3
# hyperledger/fabric 148
# docker/docker 18838
# adobe/brackets 4
# symfony/symfony-docs 7656
# symfony/symfony 16922
# diydrones/ardupilot 5008
# angular-ui/bootstrap 2265
# bcit-ci/CodeIgniter 2665
# plaindocs/travis-broken-example 206
# scm-ninja/starter-web 274
# antirez/redis 1882
# ariya/phantomjs 4
# esp8266/Arduino 3
# scala/scala 1
# LarryMad/recipes 3924
# libgdx/libgdx 1
# gogits/gogs 1
# kubernetes/kubernetes 38498
# karan/Projects 69
# racaljk/hosts 470
# pandas-dev/pandas 9113
# facebook/react 6980
# facebook/folly 405
# facebook/.ipynb_checkpoints 0
# facebook/pop 1
# sindresorhus/awesome 1114
# openssl/openssl 4301
# servo/servo 12763
# Smoothieware/Smoothieware 1
# mozilla-b2g/gaia 31580
# iluwatar/java-design-patterns 3
# lord/slate 505
# impress/impress.js 290
# zxing/zxing 217
# Atom/atom 1
# thoughtbot/paperclip 805
# aporter/coursera-android 1
# angular/angular-seed 231
# angular/angular-cli 2845
# angular/angular 9070
# angular/angular.js 7772
# TryGhost/Ghost 3
# getify/You-Dont-Know-JS 3
# scikit-learn/scikit-learn 6118
# spf13/hugo 1899
# h5bp/html5-boilerplate 908
# FancyCoder0/.ipynb_checkpoints 0
# FancyCoder0/INFOX 63
# joomla/joomla-cms 13976
# daneden/animate.css 3
# terraform-aws-modules/terraform-aws-ec2-instance 17
# JuliaLang/julia 13556
# SnapKit/Masonry 127
# hashicorp/terraform 8080
# barryclark/jekyll-now 964
# ossu/computer-science 2
# gitlabhq/gitlabhq 3598
# SwiftyJSON/SwiftyJSON 375
# pytorch/vision 293
# StephenGrider/ReduxSimpleStarter 108
# x0rz/EQGRP 1
# lewagon/dotfiles 23
# moby/moby 18839
# yiisoft/yii2 1
# vuejs/vue 1
# vuejs/awesome-vue 1
# git/git 442
# akveo/ng2-admin 637
# akveo/ngx-admin 3
# code4craft/webmagic 85
# jtleek/datasharing 487
# learn-co-students/javascript-intro-to-functions-lab-bootcamp-prep-000 1
# necolas/normalize.css 319
# wakaleo/game-of-life 1
# mathiasbynens/dotfiles 512
# cocos2d/cocos2d-x 14644
# caskroom/homebrew-cask 2
# AHAAAAAAA/PokemonGo-Map 3
# aosabook/500lines 3
# FezVrasta/bootstrap-material-design 135
# gabrielecirulli/2048 300
# mitsuhiko/flask 1309
# rapid7/metasploit-framework 1
# github/linguist 5
# github/gitignore 2729
# BVLC/caffe 2140
# hammerjs/hammer.js 233
# imathis/octopress 800
# "\nwith open('data/msr_repo_list.txt') as f:\n    for t in f.readlines():\n        t = t.strip()    \n        pr = os.listdir('/DATA/luyao/pr_data/%s' % t)\n        print(t, len(pr))\n"

# %%
from main import *
num = 0
with open('data/msr_positive_pairs.txt') as f:
    for l in f.readlines():
        r, n1, n2 = l.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        try:
            if check_too_big(p1) or check_too_big(p2):
                print(l.strip())
                for p in [p1, p2]:
                    print(p['additions'], p['deletions'], p['changed_files'], p['comments'])
                print('---------')
        except:
            num += 1
            pass
print(num)
