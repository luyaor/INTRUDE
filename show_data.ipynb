# %%
from comp import *
from git import *
from clf import *

files = [
'/home/luyao/PR_get/INTRUDE/data/clf/manual_label_false.txt',
#'/home/luyao/PR_get/INTRUDE/data/clf/manual_label_true.txt',
'/home/luyao/PR_get/INTRUDE/data/clf/openpr_label_false.txt',
#'/home/luyao/PR_get/INTRUDE/data/clf/openpr_label_true.txt'
]

num1, num2 = 0, 0

def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

def check_meaningless(title):
    title = title.lower()
    if 'revert' in title:
        return True
    if 'typo' in title:
        return True
    if (('updat' in title) or ('upgrade' in title)) and ('to' in title.split(' ')) and (get_version_numbers(title)):
        return True
    if (('updat' in title) or ('upgrade' in title)) and (('version' in title) or ('doc' in title)):
        return True
    if 'readme' in title:
        return True
    if 'changelog' in title:
        return True

    return False


for file in files:
    for t in open(file).readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        def add(p1):
            file_list = fetch_pr_info(p1)
            return sum([x["LOC"]['add'] for x in file_list])
        def dele(p1):
            file_list = fetch_pr_info(p1)
            return sum([x["LOC"]['del'] for x in file_list])
        
        
        
        '''
        if check_meaningless(p1['title']) or check_meaningless(p2['title']):
            pass
        else:
            continue
            
        init_model_with_repo(r)
        
        if ret['code'][0] >= 0.6:
            continue
        '''
            
        # ret = get_pr_sim(p1, p2)
        
        '''
        if ret['pattern'][0] == 1:
            continue
        '''
        
        if (check_meaningless(p1['title']) or check_meaningless(p2['title'])) and (check_pattern(p1, p2) != 1):
            
            num1 += 1
            
        else:
            num2 +=1 
            continue
        
        print(check_meaningless(p1['title']), check_meaningless(p2['title']), p1['merged_at'], p2['merged_at'])
        
        print(t.strip(), 'line=', '+%d,-%d' % (add(p1), dele(p1)) , '\t', '+%d,-%d' % (add(p2), dele(p2)))
        print(p1['title'])
        print(p2['title'])
        
        # print(ret)
        try:
            print('pattern', check_pattern(p1, p2))
        except:
            pass
        print('------')
        
        
    
        '''
        file_list = fetch_pr_info(p1)
        if len(file_list) <= 10:
            #print(p1['title'], ':', [x['name'] for x in file_list])
            t = sum([x["LOC"]['add'] for x in file_list])
            if t <= 10:
                print(r, n1, n2, p1['title'], ':', t)
        ''' 

print(num1, num2)

# %%
from comp import *
from git import *
from clf import *

num, tot = 0, 0

#file = 'data/clf/msr_positive_pairs.txt'
# file = '/home/luyao/PR_get/INTRUDE/data/clf/manual_label_false.txt'
file = '/home/luyao/PR_get/INTRUDE/data/clf/manual_label_true.txt'


for t in open(file).readlines():
    tot += 1

    r, n1, n2 = t.split()
    p1 = get_pull(r, n1)
    p2 = get_pull(r, n2)
    
    file_list1 = fetch_pr_info(p1)
    file_list2 = fetch_pr_info(p2)
    
    #print(file_list1)
    #print(file_list2)
    
    li1 = []
    for file in file_list1:
        li1.append(os.path.basename(file['name']))
    
    li2 = []
    for file in file_list2:
        li2.append(os.path.basename(file['name']))
    
    li = list(set(li1) & set(li2))
    ps = [os.path.splitext(file)[0] for file in li]
    
    #ps = li
    
    ok = False
    names = []
    
    s1 = set(p1['title'].lower().split())
    s2 = set(p2['title'].lower().split())
    s3 = s1 & s2
    
    for p in ps:
        if (p.lower() in s1) or (p.lower() in s2):
            ok = True
            names.append(p)
    
    ok2 = False
    names2 = []
    for p in ps:
        if (p in p1['title']) and (p in p2['title']):
            ok2 = True
            names2.append(p)
    
    '''
    if ok != ok2:
        print(p1['title'])
        print(p2['title'])
        print(names)
        print(names2)
        print('-----')
    '''
    
    if ok2:
        num += 1

    
    if ok2:
        print(p1['title'])
        print(p2['title'])
        print(names)
        print('------')
    
    
    #break

print(num, tot, 1.0 * num / tot)

# %%
from git import *

num = 0
tot = 0
tot2 = 0
tot3 = 0
totn = 0

ff = open('data/msr_r.txt', 'w')

with open('data/clf/msr_positive_pairs.txt') as f:
    for t in f.readlines():
        r, n1, n2 = t.strip().split()
        
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        if 'changed_files' in p1:
            if p1['changed_files'] > 0:
                tot += p1["additions"]
                tot2 += p1["deletions"]
                tot3 += p1["changed_files"]
                totn += 1
                
                print(p1["changed_files"], p1["additions"], p1["deletions"], file=ff)
        
        if 'changed_files' in p2:
            if p2['changed_files'] > 0:
                tot += p2["additions"]
                tot2 += p2["deletions"]
                tot3 += p2["changed_files"]
                totn += 1
                
                print(p2["changed_files"], p2["additions"], p2["deletions"], file=ff)
        
        '''
        if check_too_big(p1) or check_too_big(p2):
            print(t)
            try:
                print(p1["changed_files"], p1["additions"], p1["deletions"])
                print(p2["changed_files"], p2["additions"], p2["deletions"])
            except:
                pass
            
            print('-------')
            num += 1
        '''

print(1.0 * tot / totn)
print(1.0 * tot2 / totn)
print(1.0 * tot3 / totn)

print(totn)
ff.close()

# %%
#file = 'data/clf/msr_positive_pairs_feature_vector_text_lsi_code_tfidf_ori_and_overlap_X_and_Y.txt'
#file = 'data/clf/rly_false_pairs_feature_vector_text_tfidf_code_tfidf_ori_and_overlap_X_and_Y.txt'
file = 'data/clf/first_nn.txt'

from git import *

# from clf import *

# c = classify()

total, num = 0, 0


vets = []

with open(file) as f:
    for t in f.readlines():
        v = t.replace('[','').replace(']','').replace(',','').split()
        r, n1, n2 = v[0], v[1], v[2]
        label = v[-1]
        try:
            vet = [float(x) for x in v[3:-1]]
        except:
            print('error', t)
            
        vets.append(vet)

        '''
        if check_large(get_pull(r, n1)) and check_large(get_pull(r, n2)):
            total += c.predict_proba([vet])[0][1]
            num += 1
        '''

from numpy import array

vets = array(vets)

for i in range(9):
    l = len(vets[:,i])
    print(1.0 * sum(vets[:,i]) / l)
    
for i in range(9):
    print(max(vets[:,i]), min(vets[:,i]))

# %%
'''
def pp(p):
    if check_large(p):
        files = fetch_pr_info(p)
        l = len(files)
        
        print(p['base']['repo']['full_name'], p['number'], l)
        #print('---')
'''

from git import *
from comp import *
from clf import *

cnt = 0
with open('data/clf/first_nondup.txt') as f:
    for t in f.readlines():
        r, n1, n2 = t.strip().split()
        
        if not (r == 'kubernetes/kubernetes'):
            continue
            
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        t = get_pr_sim_vector(p1, p2)
        
        cnt += 1
        
        if cnt % 10 == 0:
            print(cnt)

        '''
        print(p1["additions"], p2["additions"], file=out)
        
        if check_large(p1) or check_large(p2):
            print(t.strip())
            #print(get_pr_sim(p1, p2)['code'])
            #print(len(fetch_pr_info(p1)), len(fetch_pr_info(p2)))
        '''
        
out.close()

# %%
from git import *


with open('data/clf/second_msr_pairs_nolarge.txt') as f:
    for t in f.readlines():
        r, n1, n2 = t.strip().split()
        if n1 > n2:
            n1, n2 = n2, n1
        
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        try:
            print(p1["additions"], p2["additions"])
        except:
            print('error!', t)
        '''
        if check_large(p1) or check_large(p2):
            print('error')
            print(t)
        '''

# %%
from git import *

cnt = 0

with open('data/clf/first_nondup.txt') as f:
    for t in f.readlines():
        r, n1, n2 = t.strip().split()
        def check(r, n):
            path = '/DATA/luyao/pr_data/%s/%s/raw_diff.json' % (r, n)
            
            fetch_file_list(get_pull(r, n))
            
            try:
                t = os.path.getsize(path)
            except:
                t = 0
            
            '''
            if t >= 50 * 1024:
                print(r, n, 'size=', t)
            '''
            
        check(r, n1)
        check(r, n2)
        
        cnt += 1
        if cnt % 1000 == 0:
            print(cnt)

# %%
import os

from git import *
from sklearn.utils import shuffle

# choose = ['cocos2d/cocos2d-x', 'dotnet/corefx', 'django/django', 'angular/angular.js', 'JuliaLang/julia', 'ceph/ceph', 'joomla/joomla-cms', 'facebook/react', 'hashicorp/terraform', 'rails/rails', 'docker/docker', 'elastic/elasticsearch', 'emberjs/ember.js', 'ansible/ansible']

choose = ['facebook/react', 'moby/moby']

for repo in choose:
    print(repo)
    cnt = 0
    nums = os.listdir('/DATA/luyao/pr_data/%s' % repo)
    # nums = shuffle(nums)[:1000]
    for num in nums:
        cnt += 1
        if cnt % 100 == 0:
            print(cnt)
        if num.isdigit():
            if not os.path.exists('/DATA/luyao/pr_data/%s/%s/parse_diff.json' % (repo, num)):
                p = get_pull(repo, num)
                if not check_large(p):
                    len_f = len(fetch_pr_info(p))


import os
from git import *
from sklearn.utils import shuffle

# choose = ['cocos2d/cocos2d-x', 'dotnet/corefx', 'django/django', 'angular/angular.js', 'JuliaLang/julia', 'ceph/ceph', 'joomla/joomla-cms', 'facebook/react', 'hashicorp/terraform', 'rails/rails', 'docker/docker', 'elastic/elasticsearch', 'emberjs/ember.js', 'ansible/ansible']

# choose = ['elastic/elasticsearch', 'emberjs/ember.js', 'ansible/ansible']

choose = ['moby/moby']

for repo in choose:
    print(repo)
    cnt = 0
    nums = os.listdir('/DATA/luyao/pr_data/%s' % repo)
    nums = shuffle(nums)[:5000]
    for num in nums:
        cnt += 1
        if cnt % 100 == 0:
            print(cnt)
        if num.isdigit():
            if not os.path.exists('/DATA/luyao/pr_data/%s/%s/parse_diff.json' % (repo, num)):
                p = get_pull(repo, num)
                if not check_too_big(p):
                    print(repo, num)

# %%
from git import *
from datetime import datetime, timedelta

file = 'data/clf/msr_positive_pairs.txt'

def get_time(t):
    return datetime.strptime(t, "%Y-%m-%dT%H:%M:%SZ")

def check(pull, pullA):
    # same author
    if pullA["user"]["id"] == pull["user"]["id"]:
        return True

    # case of following up work (not sure)
    if str(pull["number"]) in (get_pr_and_issue_numbers(pullA["title"]) + \
                               get_pr_and_issue_numbers(pullA["body"])):
        return True
    
    if abs((get_time(pullA["updated_at"]) - get_time(pull["updated_at"])).days) >= 5 * 365: # more than 4 years
        return True

    return False

def c2(pull, pullA):
    if (pull["merged_at"] is not None) and \
            (get_time(pull["merged_at"]) < get_time(pullA["created_at"])) and \
            ((get_time(pullA["created_at"]) - get_time(pull["merged_at"])).days >= 14):
        return True
    
    return False

num = 0
for t in open(file).readlines():
    tt = t.split()
    r, n1, n2 = tt[0], tt[1], tt[2]
    if n1 > n2:
        n1, n2 = n2, n1

    p1 = get_pull(r, n1)
    p2 = get_pull(r, n2)
    
    # z = t.strip()
    flag = 'False'
    if c2(p1, p2):
        z += " True"
        num += 1
        flag = 'True'
        print(t.strip(), (get_time(p2["created_at"]) - get_time(p1["merged_at"])).days)
    #print(flag)

print(num)
# Out:
# ceph/ceph	6940	4350 245
# docker/docker	30290	29121 45
# facebook/react	7819	4344 413
# kubernetes/kubernetes	45455	40210 106
# kubernetes/kubernetes	37269	275 878
# kubernetes/kubernetes	44496	39342 102
# saltstack/salt	16266	15780 14
# rails/rails	14030	12413 134
# rust-lang/rust	9753	7297 103
# zendframework/zf2	5904	5802 20
# rails/rails	23972	23684 14
# saltstack/salt	32086	31660 18
# JuliaLang/julia	18936	18658 18
# rust-lang/rust	26190	21830 127
# scikit-learn/scikit-learn	4802	1292 945
# rails/rails	19096	12177 441
# facebook/react	8647	8328 28
# facebook/react	7326	3913 412
# symfony/symfony	6753	6259 35
# saltstack/salt	39228	38316 51
# symfony/symfony-docs	7528	2349 1426
# symfony/symfony	7386	6515 75
# ceph/ceph	15543	14981 32
# cocos2d/cocos2d-x	9257	9057 17
# kubernetes/kubernetes	38546	1932 780
# symfony/symfony-docs	7527	6471 316
# symfony/symfony	13587	12355 94
# rails/rails	27254	26686 59
# elastic/elasticsearch	20219	15299 262
# facebook/react	6419	5884 66
# kubernetes/kubernetes	11219	10234 17
# hashicorp/terraform	9398	7617 68
# joomla/joomla-cms	13495	11764 123
# pydata/pandas	12598	12090 50
# joomla/joomla-cms	8574	8420 16
# docker/docker	13939	13041 38
# docker/docker	4270	3956 14
# facebook/react	9385	5718 450
# servo/servo	8241	33 1190
# symfony/symfony	12550	10786 212
# twbs/bootstrap	15384	15137 31
# servo/servo	16465	14771 106
# twbs/bootstrap	19055	18908 14
# hashicorp/terraform	2411	2086 24
# twbs/bootstrap	15423	15126 38
# rails/rails	25178	20112 382
# symfony/symfony	17635	11311 496
# facebook/react	7090	144 1084
# emberjs/ember.js	12630	12344 66
# ceph/ceph	11649	11031 34
# elastic/elasticsearch	12044	11674 19
# zendframework/zf2	5618	4534 207
# zendframework/zf2	4358	3932 49
# 53

# %%
from git import *
from detect import *

with open('data/clf/msr_positive_pairs.txt') as f:
    for t in f.readlines():
        r, n1, n2 = t.strip().split()
        if n1 > n2:
            n1, n2 = n2, n1
        
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        if check_pro_pick(p1, p2):
            print(t)
# Out:
# text_sim_type= lsi
# code_sim_type= tfidf
# extract_sim_type= ori_and_overlap
# Data Type: ok_text_lsi_code_tfidf_ori_and_overlap
# Data Loading.........
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_nondup.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/first_nondup_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_nondup.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/second_nondup_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# --------------------------
# Model: training_set 50618 testing_set 50737 feature_length= 9
# ------ model:  boost ------
# [0.22  0.42  0.105 0.005 0.04  0.055 0.05  0.04  0.065]
# Mean Accuracy: 0.9942645406705166
# Average precision score: 0.9191
# F1 score: 0.8643
# threshold acc = 0.9942645406705166
# threshold re-call = 0.8067885117493473
# threshold precision = 0.9307228915662651
# mozilla-b2g/gaia	9428	9349
#
# mozilla-b2g/gaia	18033	18000
#
# ceph/ceph	4276	4245
#
# ceph/ceph	7415	7399
#
# cocos2d/cocos2d-x	6951	6939
#
# django/django	4115	3984
#
# dotnet/corefx	20697	20599
#
# dotnet/corefx	10460	10450
#
# dotnet/corefx	15044	14939
#
# emberjs/ember.js	11667	11660
#
# emberjs/ember.js	12908	12832
#
# emberjs/ember.js	13775	13751
#
# facebook/react	8757	8648
#
# joomla/joomla-cms	1435	1430
#
# JuliaLang/julia	14264	12503
#
# JuliaLang/julia	14098	12904
#
# pydata/pandas	16678	16677
#
# saltstack/salt	17692	17691
#
# rust-lang/rust	8982	8980
#
# rust-lang/rust	7991	7982
#
# rust-lang/rust	7657	7656
#
# rust-lang/rust	7919	7897
#
# rust-lang/rust	7738	7736
#
# rust-lang/rust	23796	23727
#
# rust-lang/rust	42418	42413
#
# rust-lang/rust	20677	20562
#
# rust-lang/rust	8080	8074
#
# saltstack/salt	26696	26694
#
# saltstack/salt	26136	26117
#
# rust-lang/rust	9316	9315
#
# rust-lang/rust	9643	9594
#
# saltstack/salt	20535	20509
#
# rust-lang/rust	7270	7226
#
# rust-lang/rust	7707	7676
#
# rust-lang/rust	7865	7858
#
# servo/servo	1134	1133
#
# rails/rails	5927	5710
#
# rails/rails	10905	10846
#
# rails/rails	23816	23792
#
# ceph/ceph	10797	10787
#
# ceph/ceph	11618	11612
#
# rails/rails	26266	24962
#
# dotnet/corefx	4160	4157
#
# symfony/symfony	8451	7887
#
# angular/angular.js	2260	2216
#
# ceph/ceph	6039	5714
#
# saltstack/salt	38829	38266
#
# ceph/ceph	3236	3233
#
# nodejs/node	11828	8491
#
# scikit-learn/scikit-learn	3574	1176
#
# saltstack/salt	22626	22406
#
# symfony/symfony	12967	12963
#
# symfony/symfony	12778	12522
#
# angular/angular.js	12524	12477
#
# symfony/symfony	10500	10498
#
# symfony/symfony	6603	6583
#
# symfony/symfony	6293	5401
#
# symfony/symfony	6583	6450
#
# ceph/ceph	14487	14394
#
# joomla/joomla-cms	12861	12846
#
# symfony/symfony	17434	16202
#
# symfony/symfony-docs	4861	4840
#
# symfony/symfony-docs	4861	4847
#
# symfony/symfony-docs	4861	4849
#
# symfony/symfony-docs	7800	7128
#
# ceph/ceph	10797	10651
#
# emberjs/ember.js	2892	2485
#
# symfony/symfony-docs	4861	4814
#
# ceph/ceph	9581	8754
#
# symfony/symfony-docs	3459	3455
#
# hashicorp/terraform	7994	7909
#
# hashicorp/terraform	3064	3019
#
# symfony/symfony-docs	4861	4806
#
# symfony/symfony-docs	4861	4810
#
# hashicorp/terraform	1827	1526
#
# docker/docker	6178	6061
#
# facebook/react	8764	8655
#
# JuliaLang/julia	11906	11828
#
# ceph/ceph	14577	14535
#
# ceph/ceph	8903	8470
#
# mozilla-b2g/gaia	28433	28349
#
# zendframework/zf2	6695	6615
#
# ceph/ceph	10678	10644
#
# ceph/ceph	11466	11056
#
# ceph/ceph	13179	13001
#
# ceph/ceph	11433	10793
#
# joomla/joomla-cms	16146	13500
#
# joomla/joomla-cms	1365	1362
#
# joomla/joomla-cms	1365	1361
#
# mozilla-b2g/gaia	21899	21887
#
# facebook/react	4157	2263
#
# ceph/ceph	14088	13658
#
# joomla/joomla-cms	2111	2029
#
# joomla/joomla-cms	1365	1356
#
# twbs/bootstrap	16628	14552
#
# JuliaLang/julia	21184	12584
#
# JuliaLang/julia	19863	19856
#
# ceph/ceph	9264	9242
#
# servo/servo	14286	14269
#
# ceph/ceph	5730	4861
#
# kubernetes/kubernetes	44500	42007
#
# django/django	2425	2366
#
# django/django	1758	1752
#
# JuliaLang/julia	21299	18688
#
# kubernetes/kubernetes	30848	29741
#
# rust-lang/rust	20653	20641
#
# scikit-learn/scikit-learn	6436	6431
#
# angular/angular.js	5084	4872
#
# symfony/symfony	22793	22786
#
# ansible/ansible	19228	19049
#
# ceph/ceph	11679	11643
#
# elastic/elasticsearch	19594	19489
#
# rust-lang/rust	22367	22352
#
# ceph/ceph	14576	14535
#
# ceph/ceph	13204	12045
#
# ceph/ceph	8979	8846
#
# symfony/symfony	17635	11311
#
# symfony/symfony	5522	4937
#
# hashicorp/terraform	12913	12879
#
# ceph/ceph	11743	11734
#
# ceph/ceph	8027	8024
#
# ceph/ceph	8627	8590
#
# ceph/ceph	8139	8015
#
# django/django	5220	4250
#
# pydata/pandas	5950	4680
#
# zendframework/zf2	1178	1165
#
# zendframework/zf2	4358	3932
#
# saltstack/salt	33866	33830
#
# symfony/symfony	9199	8940
#
# rust-lang/rust	19705	19701
#
# saltstack/salt	22952	22951
#
# ceph/ceph	11628	11453
#
# ceph/ceph	5309	5173
#
# kubernetes/kubernetes	28053	28052
#
# servo/servo	4116	4096
#
# ceph/ceph	6756	6694
#
# ceph/ceph	13178	12997
#
# ceph/ceph	11626	11556
#
# ceph/ceph	13643	13450
#
# ceph/ceph	4890	4687
#
# ceph/ceph	13270	13255
#
# ceph/ceph	4887	4776
#
# rust-lang/rust	37862	36895
#
# ceph/ceph	11990	11646
#
# ceph/ceph	13506	13450
#
# angular/angular.js	2273	1084
#
# ceph/ceph	847	710
#
# ceph/ceph	13358	13269
#
# ceph/ceph	14616	13592
#
# ceph/ceph	13505	13503
#
# ceph/ceph	13332	13300
#
# ceph/ceph	8108	8060
#
# cocos2d/cocos2d-x	11583	11441
#
# kubernetes/kubernetes	37140	36826
#
# kubernetes/kubernetes	19884	19725
#
# kubernetes/kubernetes	43719	42815
#
# kubernetes/kubernetes	39634	39632
#
# rust-lang/rust	38466	38450
#
# rust-lang/rust	7202	7146
#
# rust-lang/rust	11405	11398
