# %%
from comp import *
from git import *
from clf import *

files = [
#'/home/luyao/PR_get/INTRUDE/data/clf/manual_label_false.txt',
'/home/luyao/PR_get/INTRUDE/data/clf/manual_label_true.txt',
#'/home/luyao/PR_get/INTRUDE/data/clf/openpr_label_false.txt',
'/home/luyao/PR_get/INTRUDE/data/clf/openpr_label_true.txt'
]

def check_meaningless(title):
    title = title.lower()
    if 'revert' in title:
        return True
    if 'typo' in title:
        return True
    if (('updat' in title) or ('upgrade' in title)) and ('to' in title.split(' ')):
        return True
    if (('updat' in title) or ('upgrade' in title)) and (('version' in title) or ('doc' in title)):
        return True
    if 'readme' in title:
        return True
    
    return False


for file in files:
    for t in open(file).readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        def add(p1):
            file_list = fetch_pr_info(p1)
            return sum([x["LOC"]['add'] for x in file_list])
        def dele(p1):
            file_list = fetch_pr_info(p1)
            return sum([x["LOC"]['del'] for x in file_list])
        
        if check_meaningless(p1['title']) or check_meaningless(p2['title']):
            pass
        else:
            continue
            
        
        init_model_with_repo(r)
        
        ret = get_pr_sim(p1, p2)
        
        if ret['code'][0] >= 0.6:
            continue
        if ret['pattern'][0] == 1:
            continue
        
        print(t.strip(), 'line=', '+%d,-%d' % (add(p1), dele(p1)) , '\t', '+%d,-%d' % (add(p2), dele(p2)))
        print(p1['title'])
        print(p2['title'])
        
        
        print(ret)
        print('------')
        
    
        '''
        file_list = fetch_pr_info(p1)
        if len(file_list) <= 10:
            #print(p1['title'], ':', [x['name'] for x in file_list])
            t = sum([x["LOC"]['add'] for x in file_list])
            if t <= 10:
                print(r, n1, n2, p1['title'], ':', t)
        '''
# Out:
# init nlp model with laravel/framework data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# laravel/framework 4138 2678 line= +24,-13 	 +31,-18
# Fixed sockets not working in Laravel
# Update MySqlConnector.php to fix a bug when the unix_socket param is used
# {'title': [0.18263935856845182], 'desc': [0.5410406478072021], 'code': [0.5113864461715458, 0.5113864461715458], 'file_list': [1.0, 2], 'location': [0.9173553719008265, 0.9173553719008265], 'pattern': [0], 'time': [158]}
# ------
# init nlp model with laravel/framework data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# init nlp model with Apple/swift data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# init nlp model with elastic/elasticsearch data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# elastic/elasticsearch 9145 8347 line= +413,-189 	 +5568,-4603
# Upgrade to Lucene 5.0.0-snapshot-1649544.
# Upgrade master to lucene 5.0 snapshot
# {'title': [0.9168055005942074], 'desc': [0.3541088583734097], 'code': [0.27801185447683846, 0.23319412634699774], 'file_list': [0.07407407407407407, 40], 'location': [0.11078025638437468, 0.6747617583768829], 'pattern': [-1], 'time': [61]}
# ------
# init nlp model with elastic/elasticsearch data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# elastic/elasticsearch 21156 11803 line= +2,-9 	 +1,-3
# Update getting-started.asciidoc
# Update getting-started.asciidoc
# {'title': [1.0000000000000002], 'desc': [0.1602372378276399], 'code': [0.0, 0.0], 'file_list': [1.0, 1], 'location': [0.0, 0.0], 'pattern': [0], 'time': [493]}
# ------
# init nlp model with Apple/swift data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# init nlp model with facebook/react data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# init nlp model with rails/rails data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# init nlp model with rails/rails data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# rails/rails 17736 17231 line= +27,-24 	 +27,-24
# Update ActiveRecord and ActiveModel README.rdoc links
# Fix ActiveModel, ActiveRecord, ActiveJob README links
# {'title': [0.7353874326774846], 'desc': [0.0], 'code': [0.0, 0.0], 'file_list': [0.6666666666666666, 2], 'location': [0.9625850340136054, 1.0], 'pattern': [0], 'time': [44]}
# ------
# init nlp model with Homebrew/homebrew-cask data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# Homebrew/homebrew-cask 43181 43151 line= +3,-3 	 +2,-2
# Update visual-studio-code to 1.19.3,7c4205b5c6e52a53b81c69d2b2dc8a627abaa0ba
# Update visual-studio-code to 1.19.3,554a9c6dcd8b0636ace6f1c64e13e12adf0fcd1d
# {'title': [1.0], 'desc': [1.0], 'code': [0.0, 0.0], 'file_list': [1.0, 1], 'location': [1.0, 1.0], 'pattern': [0], 'time': [1]}
# ------
# init nlp model with Homebrew/homebrew-cask data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# init nlp model with Homebrew/homebrew-cask data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# init nlp model with hashicorp/terraform data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
