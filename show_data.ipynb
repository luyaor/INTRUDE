# %%
from comp import *
from git import *
from clf import *

files = [
'/home/luyao/PR_get/INTRUDE/data/clf/manual_label_false.txt',
#'/home/luyao/PR_get/INTRUDE/data/clf/manual_label_true.txt',
'/home/luyao/PR_get/INTRUDE/data/clf/openpr_label_false.txt',
#'/home/luyao/PR_get/INTRUDE/data/clf/openpr_label_true.txt'
]

num1, num2 = 0, 0

def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

def check_meaningless(title):
    title = title.lower()
    if 'revert' in title:
        return True
    if 'typo' in title:
        return True
    if (('updat' in title) or ('upgrade' in title)) and ('to' in title.split(' ')) and (get_version_numbers(title)):
        return True
    if (('updat' in title) or ('upgrade' in title)) and (('version' in title) or ('doc' in title)):
        return True
    if 'readme' in title:
        return True
    if 'changelog' in title:
        return True

    return False


for file in files:
    for t in open(file).readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        def add(p1):
            file_list = fetch_pr_info(p1)
            return sum([x["LOC"]['add'] for x in file_list])
        def dele(p1):
            file_list = fetch_pr_info(p1)
            return sum([x["LOC"]['del'] for x in file_list])
        
        
        
        '''
        if check_meaningless(p1['title']) or check_meaningless(p2['title']):
            pass
        else:
            continue
            
        init_model_with_repo(r)
        
        if ret['code'][0] >= 0.6:
            continue
        '''
            
        # ret = get_pr_sim(p1, p2)
        
        '''
        if ret['pattern'][0] == 1:
            continue
        '''
        
        if (check_meaningless(p1['title']) or check_meaningless(p2['title'])) and (check_pattern(p1, p2) != 1):
            
            num1 += 1
            
        else:
            num2 +=1 
            continue
        
        print(check_meaningless(p1['title']), check_meaningless(p2['title']), p1['merged_at'], p2['merged_at'])
        
        print(t.strip(), 'line=', '+%d,-%d' % (add(p1), dele(p1)) , '\t', '+%d,-%d' % (add(p2), dele(p2)))
        print(p1['title'])
        print(p2['title'])
        
        # print(ret)
        try:
            print('pattern', check_pattern(p1, p2))
        except:
            pass
        print('------')
        
        
    
        '''
        file_list = fetch_pr_info(p1)
        if len(file_list) <= 10:
            #print(p1['title'], ':', [x['name'] for x in file_list])
            t = sum([x["LOC"]['add'] for x in file_list])
            if t <= 10:
                print(r, n1, n2, p1['title'], ':', t)
        ''' 

print(num1, num2)

# %%
from comp import *
from git import *
from clf import *

num, tot = 0, 0

#file = 'data/clf/msr_positive_pairs.txt'
# file = '/home/luyao/PR_get/INTRUDE/data/clf/manual_label_false.txt'
file = '/home/luyao/PR_get/INTRUDE/data/clf/manual_label_true.txt'


for t in open(file).readlines():
    tot += 1

    r, n1, n2 = t.split()
    p1 = get_pull(r, n1)
    p2 = get_pull(r, n2)
    
    file_list1 = fetch_pr_info(p1)
    file_list2 = fetch_pr_info(p2)
    
    #print(file_list1)
    #print(file_list2)
    
    li1 = []
    for file in file_list1:
        li1.append(os.path.basename(file['name']))
    
    li2 = []
    for file in file_list2:
        li2.append(os.path.basename(file['name']))
    
    li = list(set(li1) & set(li2))
    ps = [os.path.splitext(file)[0] for file in li]
    
    #ps = li
    
    ok = False
    names = []
    
    s1 = set(p1['title'].lower().split())
    s2 = set(p2['title'].lower().split())
    s3 = s1 & s2
    
    for p in ps:
        if (p.lower() in s1) or (p.lower() in s2):
            ok = True
            names.append(p)
    
    ok2 = False
    names2 = []
    for p in ps:
        if (p in p1['title']) and (p in p2['title']):
            ok2 = True
            names2.append(p)
    
    '''
    if ok != ok2:
        print(p1['title'])
        print(p2['title'])
        print(names)
        print(names2)
        print('-----')
    '''
    
    if ok2:
        num += 1

    
    if ok2:
        print(p1['title'])
        print(p2['title'])
        print(names)
        print('------')
    
    
    #break

print(num, tot, 1.0 * num / tot)

# %%
from git import *

num = 0
tot = 0
tot2 = 0
tot3 = 0
totn = 0

ff = open('data/msr_r.txt', 'w')

with open('data/clf/msr_positive_pairs.txt') as f:
    for t in f.readlines():
        r, n1, n2 = t.strip().split()
        
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        if 'changed_files' in p1:
            if p1['changed_files'] > 0:
                tot += p1["additions"]
                tot2 += p1["deletions"]
                tot3 += p1["changed_files"]
                totn += 1
                
                print(p1["changed_files"], p1["additions"], p1["deletions"], file=ff)
        
        if 'changed_files' in p2:
            if p2['changed_files'] > 0:
                tot += p2["additions"]
                tot2 += p2["deletions"]
                tot3 += p2["changed_files"]
                totn += 1
                
                print(p2["changed_files"], p2["additions"], p2["deletions"], file=ff)
        
        '''
        if check_too_big(p1) or check_too_big(p2):
            print(t)
            try:
                print(p1["changed_files"], p1["additions"], p1["deletions"])
                print(p2["changed_files"], p2["additions"], p2["deletions"])
            except:
                pass
            
            print('-------')
            num += 1
        '''

print(1.0 * tot / totn)
print(1.0 * tot2 / totn)
print(1.0 * tot3 / totn)

print(totn)
ff.close()

# %%
#file = 'data/clf/msr_positive_pairs_feature_vector_text_lsi_code_tfidf_ori_and_overlap_X_and_Y.txt'
#file = 'data/clf/rly_false_pairs_feature_vector_text_tfidf_code_tfidf_ori_and_overlap_X_and_Y.txt'
file = 'data/clf/first_nn.txt'

from git import *

# from clf import *

# c = classify()

total, num = 0, 0


vets = []

with open(file) as f:
    for t in f.readlines():
        v = t.replace('[','').replace(']','').replace(',','').split()
        r, n1, n2 = v[0], v[1], v[2]
        label = v[-1]
        try:
            vet = [float(x) for x in v[3:-1]]
        except:
            print('error', t)
            
        vets.append(vet)

        '''
        if check_large(get_pull(r, n1)) and check_large(get_pull(r, n2)):
            total += c.predict_proba([vet])[0][1]
            num += 1
        '''

from numpy import array

vets = array(vets)

for i in range(9):
    l = len(vets[:,i])
    print(1.0 * sum(vets[:,i]) / l)
    
for i in range(9):
    print(max(vets[:,i]), min(vets[:,i]))

# %%
'''
def pp(p):
    if check_large(p):
        files = fetch_pr_info(p)
        l = len(files)
        
        print(p['base']['repo']['full_name'], p['number'], l)
        #print('---')
'''

from git import *
from comp import *
from clf import *

cnt = 0
with open('data/clf/first_nondup.txt') as f:
    for t in f.readlines():
        r, n1, n2 = t.strip().split()
        
        if not (r == 'kubernetes/kubernetes'):
            continue
            
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        t = get_pr_sim_vector(p1, p2)
        
        cnt += 1
        
        if cnt % 10 == 0:
            print(cnt)

        '''
        print(p1["additions"], p2["additions"], file=out)
        
        if check_large(p1) or check_large(p2):
            print(t.strip())
            #print(get_pr_sim(p1, p2)['code'])
            #print(len(fetch_pr_info(p1)), len(fetch_pr_info(p2)))
        '''
        
out.close()

# %%
from git import *


with open('data/clf/second_msr_pairs_nolarge.txt') as f:
    for t in f.readlines():
        r, n1, n2 = t.strip().split()
        if n1 > n2:
            n1, n2 = n2, n1
        
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        try:
            print(p1["additions"], p2["additions"])
        except:
            print('error!', t)
        '''
        if check_large(p1) or check_large(p2):
            print('error')
            print(t)
        '''

# %%
from git import *

cnt = 0

with open('data/clf/first_nondup.txt') as f:
    for t in f.readlines():
        r, n1, n2 = t.strip().split()
        def check(r, n):
            path = '/DATA/luyao/pr_data/%s/%s/raw_diff.json' % (r, n)
            
            fetch_file_list(get_pull(r, n))
            
            try:
                t = os.path.getsize(path)
            except:
                t = 0
            
            '''
            if t >= 50 * 1024:
                print(r, n, 'size=', t)
            '''
            
        check(r, n1)
        check(r, n2)
        
        cnt += 1
        if cnt % 1000 == 0:
            print(cnt)
# Out:
# pydata/pandas 19848 size= 56558
# twbs/bootstrap 9476 size= 161325
# mozilla-b2g/gaia 30391 size= 41599
# scikit-learn/scikit-learn 5141 size= 33442
# rust-lang/rust 42999 size= 30955
# saltstack/salt 43203 size= 40677
# mozilla-b2g/gaia 25209 size= 37938
# scikit-learn/scikit-learn 4570 size= 91786
# saltstack/salt 46142 size= 44824
# twbs/bootstrap 12620 size= 1421556
# pydata/pandas 11462 size= 31283
# pydata/pandas 19661 size= 34846
# nodejs/node 13707 size= 34011
# mozilla-b2g/gaia 10582 size= 49321
# twbs/bootstrap 9476 size= 161325
# twbs/bootstrap 12215 size= 1238979
# kubernetes/kubernetes 55939 size= 33878
# mozilla-b2g/gaia 30391 size= 41599
# 1000
# twbs/bootstrap 22395 size= 70880
# twbs/bootstrap 16257 size= 3500132
# scikit-learn/scikit-learn 574 size= 99967
# saltstack/salt 43518 size= 35292
# symfony/symfony-docs 3613 size= 40412
# saltstack/salt 25071 size= 31158
# rust-lang/rust 31409 size= 56251
# rust-lang/rust 32007 size= 33945
# rust-lang/rust 29795 size= 36726
# pydata/pandas 20347 size= 34380
# mozilla-b2g/gaia 22781 size= 38453
# rust-lang/rust 30843 size= 74013
# scikit-learn/scikit-learn 9252 size= 58975
# kubernetes/kubernetes 46821 size= 35180
# scikit-learn/scikit-learn 1263 size= 139185
# nodejs/node 10544 size= 35700
# twbs/bootstrap 12195 size= 1405375
# servo/servo 19833 size= 58893
# rust-lang/rust 31461 size= 58856
# servo/servo 8378 size= 32359
# servo/servo 4152 size= 38197
# servo/servo 19331 size= 230432
# symfony/symfony-docs 3190 size= 59764
# twbs/bootstrap 10951 size= 202035
# scikit-learn/scikit-learn 8478 size= 41285
# twbs/bootstrap 11817 size= 203439
# symfony/symfony-docs 5083 size= 32151
# 2000
# pydata/pandas 3744 size= 30753
# symfony/symfony-docs 3613 size= 40412
# symfony/symfony 3315 size= 35192
# servo/servo 539 size= 32543
# saltstack/salt 11027 size= 50784
# servo/servo 13213 size= 35225
# rust-lang/rust 24034 size= 33193
# zendframework/zf2 7714 size= 49248
# servo/servo 10555 size= 33814
# kubernetes/kubernetes 7832 size= 43544
# twbs/bootstrap 11694 size= 625862
# twbs/bootstrap 22921 size= 54139
# zendframework/zf2 2312 size= 81588
# pydata/pandas 10507 size= 39164
# twbs/bootstrap 9966 size= 624100
# pydata/pandas 9814 size= 31909
# rust-lang/rust 15619 size= 134685
# twbs/bootstrap 10232 size= 594602
# zendframework/zf2 7714 size= 49248
# twbs/bootstrap 12972 size= 75505
# twbs/bootstrap 20258 size= 1528188
# rust-lang/rust 44736 size= 32828
# scikit-learn/scikit-learn 2295 size= 31997
# symfony/symfony-docs 4313 size= 34086
# symfony/symfony-docs 4159 size= 33683
# symfony/symfony-docs 1295 size= 56181
# servo/servo 19376 size= 869839
# twbs/bootstrap 11376 size= 569056
# 3000
# zendframework/zf2 2319 size= 52646
# scikit-learn/scikit-learn 9041 size= 32548
# zendframework/zf2 7714 size= 49248
# pydata/pandas 6889 size= 39749
# zendframework/zf2 7474 size= 31205
# kubernetes/kubernetes 1000 size= 47258
# mozilla-b2g/gaia 14579 size= 36016
# saltstack/salt 30268 size= 32633
# rust-lang/rust 40838 size= 33570
# kubernetes/kubernetes 46065 size= 36255
# rust-lang/rust 48061 size= 38195
# servo/servo 19664 size= 1463224
# servo/servo 10082 size= 33178
# kubernetes/kubernetes 61950 size= 38640
# nodejs/node 10544 size= 35700
# twbs/bootstrap 13151 size= 1768623
# pydata/pandas 9813 size= 70663
# twbs/bootstrap 12195 size= 1405375
# kubernetes/kubernetes 49180 size= 45824
# servo/servo 12294 size= 40969
# servo/servo 20519 size= 39644
# pydata/pandas 20844 size= 44011
# twbs/bootstrap 11930 size= 34706
# 4000
# servo/servo 13898 size= 92515
# twbs/bootstrap 11376 size= 569056
# scikit-learn/scikit-learn 627 size= 83055
# servo/servo 14830 size= 58288
# pydata/pandas 7599 size= 43165
# pydata/pandas 6987 size= 36885
# pydata/pandas 8741 size= 405543
# zendframework/zf2 1750 size= 37047
# mozilla-b2g/gaia 25209 size= 37938
# scikit-learn/scikit-learn 9019 size= 34140
# zendframework/zf2 7714 size= 49248
# rust-lang/rust 45595 size= 42265
# kubernetes/kubernetes 33278 size= 36798
# symfony/symfony-docs 3190 size= 59764
# scikit-learn/scikit-learn 4570 size= 91786
# rust-lang/rust 18462 size= 35834
# twbs/bootstrap 22395 size= 70880
# mozilla-b2g/gaia 31170 size= 61419
# servo/servo 13539 size= 94869
# mozilla-b2g/gaia 11430 size= 57800
# scikit-learn/scikit-learn 3224 size= 34706
# kubernetes/kubernetes 43880 size= 41745
# servo/servo 16047 size= 57188
# twbs/bootstrap 16386 size= 103143
# rust-lang/rust 36729 size= 36797
# pydata/pandas 7599 size= 43165
# pydata/pandas 9814 size= 31909
# rust-lang/rust 26561 size= 58261
# scikit-learn/scikit-learn 2631 size= 236087
# 5000
# pydata/pandas 4761 size= 41833
# twbs/bootstrap 25020 size= 30893
# servo/servo 10774 size= 68024
# nodejs/node 13707 size= 34011
# rust-lang/rust 7641 size= 139801
# rust-lang/rust 34705 size= 41316
# kubernetes/kubernetes 10422 size= 169809
# scikit-learn/scikit-learn 2700 size= 57144
# servo/servo 16282 size= 40979
# twbs/bootstrap 22395 size= 70880
# symfony/symfony-docs 5386 size= 74064
# mozilla-b2g/gaia 11934 size= 64312
# mozilla-b2g/gaia 31170 size= 61419
# mozilla-b2g/gaia 31695 size= 46824
# scikit-learn/scikit-learn 2949 size= 37263
# twbs/bootstrap 6111 size= 59515
# kubernetes/kubernetes 19632 size= 72321
# pydata/pandas 19473 size= 50876
# mozilla-b2g/gaia 14604 size= 36342
# twbs/bootstrap 10265 size= 199481
# mozilla-b2g/gaia 26218 size= 34798
# twbs/bootstrap 9424 size= 156652
# servo/servo 13061 size= 54716
# scikit-learn/scikit-learn 4698 size= 39238
# scikit-learn/scikit-learn 4570 size= 91786
# scikit-learn/scikit-learn 8478 size= 41285
# twbs/bootstrap 10079 size= 196630
# scikit-learn/scikit-learn 5141 size= 33442
# symfony/symfony 24447 size= 36868
# scikit-learn/scikit-learn 9041 size= 32548
# 6000
# pydata/pandas 9814 size= 31909
# rust-lang/rust 15199 size= 40478
# twbs/bootstrap 9424 size= 156652
# symfony/symfony-docs 389 size= 53560
# pydata/pandas 10305 size= 36542
# twbs/bootstrap 15491 size= 110823
# servo/servo 21087 size= 40315
# mozilla-b2g/gaia 16813 size= 32807
# twbs/bootstrap 16175 size= 1053209
# pydata/pandas 19829 size= 76592
# servo/servo 11972 size= 35418
# servo/servo 17565 size= 33222
# twbs/bootstrap 12993 size= 2440358
# scikit-learn/scikit-learn 574 size= 99967
# mozilla-b2g/gaia 30391 size= 41599
# twbs/bootstrap 11697 size= 205102
# nodejs/node 10544 size= 35700
# rust-lang/rust 29316 size= 43997
# scikit-learn/scikit-learn 5371 size= 43564
# kubernetes/kubernetes 31576 size= 39762
# zendframework/zf2 4268 size= 35402
# mozilla-b2g/gaia 9546 size= 42230
# zendframework/zf2 4268 size= 35402
# 7000
# servo/servo 8378 size= 32359
# twbs/bootstrap 11928 size= 498031
# servo/servo 11058 size= 38670
# twbs/bootstrap 13151 size= 1768623
# pydata/pandas 10718 size= 36642
# servo/servo 17818 size= 36501
# scikit-learn/scikit-learn 10700 size= 40726
# servo/servo 12521 size= 37095
# scikit-learn/scikit-learn 2949 size= 37263
# kubernetes/kubernetes 32623 size= 52049
# symfony/symfony-docs 9517 size= 193206
# twbs/bootstrap 16384 size= 2578413
# kubernetes/kubernetes 46821 size= 35180
# servo/servo 1770 size= 38466
# symfony/symfony-docs 4779 size= 47697
# pydata/pandas 18931 size= 75475
# kubernetes/kubernetes 16806 size= 33966
# twbs/bootstrap 17373 size= 120234
# twbs/bootstrap 16386 size= 103143
# 8000
# servo/servo 17703 size= 48393
# pydata/pandas 13767 size= 36272
# twbs/bootstrap 23626 size= 42225
# servo/servo 14905 size= 59042
# twbs/bootstrap 9123 size= 141090
# scikit-learn/scikit-learn 5371 size= 43564
# mozilla-b2g/gaia 30937 size= 32400
# scikit-learn/scikit-learn 5560 size= 175623
# twbs/bootstrap 22985 size= 43798
# mozilla-b2g/gaia 30607 size= 32506
# mozilla-b2g/gaia 23860 size= 77881
# scikit-learn/scikit-learn 3591 size= 31721
# kubernetes/kubernetes 472 size= 39849
# symfony/symfony-docs 3613 size= 40412
# nodejs/node 13707 size= 34011
# twbs/bootstrap 24254 size= 54386
# scikit-learn/scikit-learn 2460 size= 56350
# saltstack/salt 39080 size= 83215
# servo/servo 13188 size= 31094
# rust-lang/rust 1349 size= 48268
# twbs/bootstrap 10565 size= 203969
# nodejs/node 1760 size= 50991
# twbs/bootstrap 11804 size= 286265
# scikit-learn/scikit-learn 7818 size= 43674
# rust-lang/rust 49053 size= 41971
# rust-lang/rust 11123 size= 50185
# twbs/bootstrap 11697 size= 205102
# saltstack/salt 24076 size= 57470
# nodejs/node 10746 size= 49869
# 9000
# scikit-learn/scikit-learn 2363 size= 94242
# pydata/pandas 7275 size= 62135
# twbs/bootstrap 24254 size= 54386
# rust-lang/rust 28543 size= 31835
# servo/servo 8103 size= 32503
# twbs/bootstrap 23626 size= 42225
# zendframework/zf2 3709 size= 40380
# kubernetes/kubernetes 17225 size= 44588
# servo/servo 16282 size= 40979
# rust-lang/rust 12711 size= 47693
# zendframework/zf2 1750 size= 37047
# kubernetes/kubernetes 55744 size= 37200
# saltstack/salt 23915 size= 38437
# servo/servo 11058 size= 38670
# twbs/bootstrap 11188 size= 208026
# scikit-learn/scikit-learn 2631 size= 236087
# zendframework/zf2 3709 size= 40380
# symfony/symfony-docs 9517 size= 193206
# twbs/bootstrap 17970 size= 49095
# zendframework/zf2 1750 size= 37047
# twbs/bootstrap 14903 size= 993148
# twbs/bootstrap 4257 size= 55868
# zendframework/zf2 1750 size= 37047
# zendframework/zf2 1750 size= 37047
# scikit-learn/scikit-learn 396 size= 37394
# twbs/bootstrap 12633 size= 1426810
# scikit-learn/scikit-learn 4505 size= 43677
# twbs/bootstrap 10951 size= 202035
# nodejs/node 10746 size= 49869
# servo/servo 19497 size= 1027048
# kubernetes/kubernetes 58209 size= 158698
# mozilla-b2g/gaia 22416 size= 122598
# mozilla-b2g/gaia 15004 size= 50564
# kubernetes/kubernetes 32623 size= 52049
# 10000
# twbs/bootstrap 1153 size= 46025
# pydata/pandas 20931 size= 34963
# mozilla-b2g/gaia 11157 size= 35795
# mozilla-b2g/gaia 26218 size= 34798
# pydata/pandas 9899 size= 33962
# pydata/pandas 13767 size= 36272
# kubernetes/kubernetes 38227 size= 30801
# scikit-learn/scikit-learn 144 size= 55720
# kubernetes/kubernetes 63107 size= 31368
# kubernetes/kubernetes 8844 size= 46744
# scikit-learn/scikit-learn 2295 size= 31997
# twbs/bootstrap 9718 size= 164840
# scikit-learn/scikit-learn 4505 size= 43677
# mozilla-b2g/gaia 18846 size= 63829
# twbs/bootstrap 11930 size= 34706
# pydata/pandas 3744 size= 30753
# twbs/bootstrap 23162 size= 42004
# kubernetes/kubernetes 11071 size= 39842
# twbs/bootstrap 11930 size= 34706
# scikit-learn/scikit-learn 4505 size= 43677
# rust-lang/rust 30523 size= 33067
# saltstack/salt 43518 size= 35292
# symfony/symfony-docs 809 size= 31386
# twbs/bootstrap 13594 size= 77831
# kubernetes/kubernetes 481 size= 33588
# twbs/bootstrap 17970 size= 49095
# scikit-learn/scikit-learn 6743 size= 45526
# nodejs/node 10746 size= 49869
# twbs/bootstrap 24610 size= 37051
# kubernetes/kubernetes 18714 size= 34398
# twbs/bootstrap 17384 size= 114019
# pydata/pandas 3584 size= 47644
# scikit-learn/scikit-learn 3898 size= 91191
# 11000
# symfony/symfony 13579 size= 62483
# twbs/bootstrap 13867 size= 64248
# pydata/pandas 17077 size= 36324
# servo/servo 15722 size= 65300
# mozilla-b2g/gaia 22764 size= 39016
# saltstack/salt 23324 size= 31910
# scikit-learn/scikit-learn 4905 size= 33021
# twbs/bootstrap 11928 size= 498031
# twbs/bootstrap 10265 size= 199481
# twbs/bootstrap 1153 size= 46025
# servo/servo 16586 size= 41779
# twbs/bootstrap 19990 size= 34065
# mozilla-b2g/gaia 12357 size= 568272
# zendframework/zf2 3709 size= 40380
# rust-lang/rust 29316 size= 43997
# twbs/bootstrap 20222 size= 40119
# twbs/bootstrap 11138 size= 590839
# rust-lang/rust 26955 size= 48131
# saltstack/salt 45359 size= 50334
# 12000
# twbs/bootstrap 11694 size= 625862
# rust-lang/rust 37936 size= 35973
# scikit-learn/scikit-learn 4505 size= 43677
# rust-lang/rust 38152 size= 41210
# scikit-learn/scikit-learn 3224 size= 34706
# zendframework/zf2 2319 size= 52646
# twbs/bootstrap 23626 size= 42225
# pydata/pandas 9899 size= 33962
# scikit-learn/scikit-learn 4698 size= 39238
# mozilla-b2g/gaia 11157 size= 35795
# servo/servo 13682 size= 44326
# twbs/bootstrap 10265 size= 199481
# rust-lang/rust 30969 size= 32043
# mozilla-b2g/gaia 2050 size= 56578
# twbs/bootstrap 14563 size= 3393795
# twbs/bootstrap 17384 size= 114019
# saltstack/salt 28599 size= 34711
# twbs/bootstrap 11376 size= 569056
# twbs/bootstrap 11868 size= 203385
# zendframework/zf2 1750 size= 37047
# scikit-learn/scikit-learn 5141 size= 33442
# scikit-learn/scikit-learn 620 size= 135049
# pydata/pandas 18428 size= 50691
# symfony/symfony 8634 size= 32481
# servo/servo 17703 size= 48393
# mozilla-b2g/gaia 8054 size= 70620
# kubernetes/kubernetes 17227 size= 57630
# kubernetes/kubernetes 37212 size= 45131
# pydata/pandas 8741 size= 405543
# rust-lang/rust 16883 size= 33259
# servo/servo 19377 size= 870634
# kubernetes/kubernetes 62433 size= 39005
# twbs/bootstrap 3996 size= 54798
# twbs/bootstrap 4257 size= 55868
# pydata/pandas 18577 size= 44574
# kubernetes/kubernetes 56447 size= 4409396
# scikit-learn/scikit-learn 8478 size= 41285
# symfony/symfony 1386 size= 42543
# twbs/bootstrap 1153 size= 46025
# servo/servo 12643 size= 58374
# servo/servo 3638 size= 38687
# twbs/bootstrap 22395 size= 70880
# 13000
# symfony/symfony 24447 size= 36868
# rust-lang/rust 29795 size= 36726
# kubernetes/kubernetes 31922 size= 35775
# saltstack/salt 39372 size= 72093
# zendframework/zf2 3709 size= 40380
# zendframework/zf2 3709 size= 40380
# mozilla-b2g/gaia 6483 size= 86014
# servo/servo 16934 size= 103152
# servo/servo 10555 size= 33814
# zendframework/zf2 2319 size= 52646
# twbs/bootstrap 13793 size= 98189
# twbs/bootstrap 11956 size= 691121
# servo/servo 13095 size= 79179
# pydata/pandas 10305 size= 36542
# symfony/symfony 18260 size= 34787
# servo/servo 3984 size= 39054
# rust-lang/rust 30523 size= 33067
# symfony/symfony-docs 4779 size= 47697
# servo/servo 18722 size= 66682
# twbs/bootstrap 22921 size= 54139
# pydata/pandas 11329 size= 34040
# servo/servo 15353 size= 38872
# rust-lang/rust 48735 size= 34671
# scikit-learn/scikit-learn 1246 size= 111176
# scikit-learn/scikit-learn 2700 size= 57144
# mozilla-b2g/gaia 26274 size= 39221
# rust-lang/rust 12274 size= 39405
# pydata/pandas 4761 size= 41833
# scikit-learn/scikit-learn 9252 size= 58975
# rust-lang/rust 33706 size= 40767
# scikit-learn/scikit-learn 6913 size= 34586
# twbs/bootstrap 10951 size= 202035
# 14000
# twbs/bootstrap 12633 size= 1426810
# mozilla-b2g/gaia 12359 size= 282865
# zendframework/zf2 1750 size= 37047
# pydata/pandas 20813 size= 36016
# pydata/pandas 21776 size= 39978
# symfony/symfony-docs 809 size= 31386
# twbs/bootstrap 1158 size= 47661
# symfony/symfony-docs 4427 size= 48649
# scikit-learn/scikit-learn 9078 size= 32083
# scikit-learn/scikit-learn 6743 size= 45526
# mozilla-b2g/gaia 26274 size= 39221
# saltstack/salt 23383 size= 31408
# kubernetes/kubernetes 35856 size= 35221
# mozilla-b2g/gaia 25863 size= 38709
# kubernetes/kubernetes 41487 size= 58480
# servo/servo 19748 size= 430697
# servo/servo 19313 size= 331121
# scikit-learn/scikit-learn 4505 size= 43677
# scikit-learn/scikit-learn 144 size= 55720
# pydata/pandas 6889 size= 39749
# scikit-learn/scikit-learn 5371 size= 43564
# scikit-learn/scikit-learn 3898 size= 91191
# servo/servo 7400 size= 37631
# kubernetes/kubernetes 46821 size= 35180
# twbs/bootstrap 11956 size= 691121
# twbs/bootstrap 11817 size= 203439
# 15000
# symfony/symfony 10931 size= 41711
# servo/servo 16586 size= 41779
# pydata/pandas 19641 size= 32248
# rust-lang/rust 13749 size= 32197
# twbs/bootstrap 11362 size= 57739
# servo/servo 13095 size= 79179
# rust-lang/rust 19216 size= 72013
# servo/servo 16586 size= 41779
# rust-lang/rust 15284 size= 49584
# twbs/bootstrap 16386 size= 103143
# rust-lang/rust 22971 size= 68973
# rust-lang/rust 50798 size= 44061
# servo/servo 1420 size= 39556
# scikit-learn/scikit-learn 4698 size= 39238
# rust-lang/rust 26955 size= 48131
# pydata/pandas 9813 size= 70663
# symfony/symfony-docs 4313 size= 34086
# servo/servo 17703 size= 48393
# pydata/pandas 13767 size= 36272
# mozilla-b2g/gaia 31695 size= 46824
# rust-lang/rust 22393 size= 38666
# rust-lang/rust 8008 size= 49080
# pydata/pandas 4761 size= 41833
# mozilla-b2g/gaia 25863 size= 38709
# 16000
# symfony/symfony 18260 size= 34787
# servo/servo 19436 size= 1313060
# servo/servo 17914 size= 31648
# twbs/bootstrap 8611 size= 164637
# symfony/symfony-docs 3190 size= 59764
# servo/servo 15363 size= 81576
# servo/servo 10774 size= 68024
# saltstack/salt 23383 size= 31408
# symfony/symfony-docs 4779 size= 47697
# saltstack/salt 42507 size= 32618
# zendframework/zf2 7474 size= 31205
# twbs/bootstrap 25820 size= 117345
# twbs/bootstrap 12655 size= 35664
# pydata/pandas 7275 size= 62135
# pydata/pandas 2497 size= 43009
# twbs/bootstrap 8582 size= 167597
# twbs/bootstrap 18807 size= 35134
# kubernetes/kubernetes 28916 size= 55630835
# servo/servo 11168 size= 35940
# saltstack/salt 25071 size= 31158
# servo/servo 20396 size= 58601
# servo/servo 16810 size= 116182
# scikit-learn/scikit-learn 3224 size= 34706
# rust-lang/rust 49053 size= 41971
# mozilla-b2g/gaia 22416 size= 122598
# twbs/bootstrap 10265 size= 199481
# pydata/pandas 19009 size= 33479
# rust-lang/rust 20356 size= 38835
# scikit-learn/scikit-learn 2203 size= 41919
# rust-lang/rust 29530 size= 63740
# servo/servo 19313 size= 331121
# servo/servo 14687 size= 84244
# twbs/bootstrap 16175 size= 1053209
# twbs/bootstrap 20222 size= 40119
# 17000
# twbs/bootstrap 17384 size= 114019
# twbs/bootstrap 12633 size= 1426810
# zendframework/zf2 1750 size= 37047
# scikit-learn/scikit-learn 1884 size= 41132
# scikit-learn/scikit-learn 3898 size= 91191
# scikit-learn/scikit-learn 2295 size= 31997
# pydata/pandas 4333 size= 50946
# mozilla-b2g/gaia 12838 size= 114044
# symfony/symfony 8852 size= 33397
# mozilla-b2g/gaia 30112 size= 33980
# scikit-learn/scikit-learn 2700 size= 57144
# zendframework/zf2 4268 size= 35402
# twbs/bootstrap 10656 size= 202908
# pydata/pandas 7027 size= 33907
# pydata/pandas 6889 size= 39749
# servo/servo 13723 size= 87499
# kubernetes/kubernetes 1218 size= 41068
# servo/servo 17137 size= 92279
# twbs/bootstrap 4447 size= 32891
# mozilla-b2g/gaia 6562 size= 36306
# twbs/bootstrap 22921 size= 54139
# servo/servo 14013 size= 63520
# servo/servo 16586 size= 41779
# servo/servo 15722 size= 65300
# twbs/bootstrap 22395 size= 70880
# twbs/bootstrap 14311 size= 1524348
# symfony/symfony-docs 5083 size= 32151
# pydata/pandas 7926 size= 47006
# saltstack/salt 9122 size= 42351
# twbs/bootstrap 14444 size= 3383513
# servo/servo 18847 size= 40200
# twbs/bootstrap 9966 size= 624100
# scikit-learn/scikit-learn 3376 size= 132212
# kubernetes/kubernetes 34962 size= 37930
# twbs/bootstrap 15292 size= 43689
# twbs/bootstrap 9966 size= 624100
# 18000
# twbs/bootstrap 19990 size= 34065
# scikit-learn/scikit-learn 4505 size= 43677
# mozilla-b2g/gaia 12838 size= 114044
# servo/servo 18170 size= 35094
# servo/servo 4152 size= 38197
# twbs/bootstrap 14444 size= 3383513
# pydata/pandas 19009 size= 33479
# symfony/symfony-docs 3190 size= 59764
# twbs/bootstrap 24610 size= 37051
# twbs/bootstrap 11930 size= 34706
# twbs/bootstrap 9476 size= 161325
# servo/servo 1712 size= 43185
# mozilla-b2g/gaia 16813 size= 32807
# pydata/pandas 9814 size= 31909
# servo/servo 8639 size= 38256
# twbs/bootstrap 3996 size= 54798
# servo/servo 16728 size= 50311
# nodejs/node 13707 size= 34011
# servo/servo 16970 size= 44776
# scikit-learn/scikit-learn 144 size= 55720
# servo/servo 3638 size= 38687
# twbs/bootstrap 11188 size= 208026
# servo/servo 17147 size= 35563
# servo/servo 19579 size= 1460604
# rust-lang/rust 12274 size= 39405
# mozilla-b2g/gaia 419 size= 46204
# pydata/pandas 6937 size= 78539
# servo/servo 9083 size= 42108
# scikit-learn/scikit-learn 5141 size= 33442
# 19000
# twbs/bootstrap 11362 size= 57739
# servo/servo 18117 size= 32468
# twbs/bootstrap 10565 size= 203969
# rust-lang/rust 40297 size= 36960
# saltstack/salt 4238 size= 31601
# pydata/pandas 7926 size= 47006
# symfony/symfony-docs 809 size= 31386
# twbs/bootstrap 25820 size= 117345
# twbs/bootstrap 9966 size= 624100
# scikit-learn/scikit-learn 1263 size= 139185
# twbs/bootstrap 16386 size= 103143
# rust-lang/rust 27807 size= 32783
# twbs/bootstrap 13793 size= 98189
# pydata/pandas 15451 size= 32867
# twbs/bootstrap 11933 size= 171832
# twbs/bootstrap 10584 size= 204349
# twbs/bootstrap 13793 size= 98189
# zendframework/zf2 2312 size= 81588
# servo/servo 19313 size= 331121
# servo/servo 18170 size= 35094
# twbs/bootstrap 11928 size= 498031
# twbs/bootstrap 11933 size= 171832
# twbs/bootstrap 9453 size= 161068
# kubernetes/kubernetes 17700 size= 31541
# scikit-learn/scikit-learn 6913 size= 34586
# twbs/bootstrap 9966 size= 624100
# 20000
# symfony/symfony 1386 size= 42543
# twbs/bootstrap 9424 size= 156652
# twbs/bootstrap 16384 size= 2578413
# rust-lang/rust 7641 size= 139801
# mozilla-b2g/gaia 23860 size= 77881
# kubernetes/kubernetes 26360 size= 37213
# pydata/pandas 5336 size= 47218
# pydata/pandas 18307 size= 41409
# twbs/bootstrap 15491 size= 110823
# nodejs/node 1760 size= 50991
# rust-lang/rust 40128 size= 46046
# kubernetes/kubernetes 59490 size= 76843
# twbs/bootstrap 11127 size= 205194
# twbs/bootstrap 23626 size= 42225
# kubernetes/kubernetes 22892 size= 41036
# scikit-learn/scikit-learn 588 size= 189077
# scikit-learn/scikit-learn 2790 size= 155357
# twbs/bootstrap 14847 size= 34479
# saltstack/salt 41213 size= 37611
# mozilla-b2g/gaia 30607 size= 32506
# scikit-learn/scikit-learn 4905 size= 33021
# twbs/bootstrap 23626 size= 42225
# servo/servo 7615 size= 32536
# rust-lang/rust 45737 size= 33386
# mozilla-b2g/gaia 6607 size= 37723
# scikit-learn/scikit-learn 763 size= 192779
# kubernetes/kubernetes 30121 size= 49085
# 21000
# kubernetes/kubernetes 18215 size= 32637
# mozilla-b2g/gaia 26274 size= 39221
# twbs/bootstrap 22395 size= 70880
# scikit-learn/scikit-learn 8145 size= 186260
# zendframework/zf2 3709 size= 40380
# symfony/symfony-docs 4159 size= 33683
# servo/servo 7611 size= 34017
# servo/servo 14564 size= 32273
# twbs/bootstrap 13768 size= 41950
# rust-lang/rust 30863 size= 31515
# servo/servo 7615 size= 32536
# twbs/bootstrap 9453 size= 161068
# servo/servo 17137 size= 92279
# twbs/bootstrap 9476 size= 161325
# servo/servo 19132 size= 40216
# twbs/bootstrap 11376 size= 569056
# servo/servo 20620 size= 82623
# zendframework/zf2 1750 size= 37047
# mozilla-b2g/gaia 18846 size= 63829
# pydata/pandas 19848 size= 56558
# twbs/bootstrap 699 size= 34699
# pydata/pandas 7036 size= 51470
# 22000
# pydata/pandas 9321 size= 45801
# twbs/bootstrap 12688 size= 1069215
# servo/servo 4152 size= 38197
# mozilla-b2g/gaia 15278 size= 58393
# kubernetes/kubernetes 63660 size= 68731
# rust-lang/rust 34312 size= 85586
# rust-lang/rust 44736 size= 32828
# mozilla-b2g/gaia 2473 size= 32940
# twbs/bootstrap 16386 size= 103143
# servo/servo 539 size= 32543
# twbs/bootstrap 13542 size= 1860728
# saltstack/salt 43518 size= 35292
# nodejs/node 10544 size= 35700
# twbs/bootstrap 11107 size= 383148
# servo/servo 7976 size= 40545
# scikit-learn/scikit-learn 2460 size= 56350
# twbs/bootstrap 14903 size= 993148
# twbs/bootstrap 14566 size= 766079
# servo/servo 1420 size= 39556
# servo/servo 14013 size= 63520
# zendframework/zf2 1750 size= 37047
# 23000
# twbs/bootstrap 11362 size= 57739
# twbs/bootstrap 11186 size= 205582
# twbs/bootstrap 12248 size= 1577537
# scikit-learn/scikit-learn 2700 size= 57144
# twbs/bootstrap 14563 size= 3393795
# servo/servo 21087 size= 40315
# rust-lang/rust 8008 size= 49080
# kubernetes/kubernetes 17227 size= 57630
# twbs/bootstrap 11186 size= 205582
# twbs/bootstrap 23162 size= 42004
# servo/servo 13723 size= 87499
# pydata/pandas 17077 size= 36324
# servo/servo 2751 size= 32457
# twbs/bootstrap 22985 size= 43798
# servo/servo 12294 size= 40969
# kubernetes/kubernetes 56447 size= 4409396
# mozilla-b2g/gaia 12303 size= 567680
# servo/servo 12643 size= 58374
# twbs/bootstrap 9567 size= 161523
# saltstack/salt 43518 size= 35292
# twbs/bootstrap 14903 size= 993148
# kubernetes/kubernetes 53385 size= 31785
# symfony/symfony-docs 9227 size= 104298
# twbs/bootstrap 13768 size= 41950
# rust-lang/rust 20746 size= 52931
# 24000
# pydata/pandas 5034 size= 39803
# saltstack/salt 28486 size= 45619
# mozilla-b2g/gaia 8399 size= 51028
# kubernetes/kubernetes 45745 size= 33680
# twbs/bootstrap 12248 size= 1577537
# servo/servo 17565 size= 33222
# servo/servo 15039 size= 33627
# mozilla-b2g/gaia 12838 size= 114044
# kubernetes/kubernetes 21400 size= 40926
# servo/servo 19973 size= 77933
# rust-lang/rust 45595 size= 42265
# scikit-learn/scikit-learn 5141 size= 33442
# symfony/symfony-docs 3613 size= 40412
# servo/servo 17137 size= 92279
# saltstack/salt 27718 size= 41756
# saltstack/salt 46142 size= 44824
# twbs/bootstrap 1158 size= 47661
# kubernetes/kubernetes 33451 size= 51088
# servo/servo 17199 size= 32785
# saltstack/salt 10229 size= 38933
# scikit-learn/scikit-learn 6667 size= 34822
# mozilla-b2g/gaia 362 size= 44057
# servo/servo 10082 size= 33178
# twbs/bootstrap 12105 size= 31501
# 25000
# symfony/symfony 11582 size= 34820
# scikit-learn/scikit-learn 2631 size= 236087
# kubernetes/kubernetes 30671 size= 74477
# kubernetes/kubernetes 16806 size= 33966
# rust-lang/rust 37936 size= 35973
# rust-lang/rust 34705 size= 41316
# rust-lang/rust 6418 size= 31376
# twbs/bootstrap 12215 size= 1238979
# rust-lang/rust 46523 size= 34042
# twbs/bootstrap 14667 size= 3398526
# mozilla-b2g/gaia 9189 size= 36281
# rust-lang/rust 25905 size= 49747
# rust-lang/rust 28543 size= 31835
# scikit-learn/scikit-learn 144 size= 55720
# twbs/bootstrap 12633 size= 1426810
# symfony/symfony-docs 9227 size= 104298
# rust-lang/rust 34599 size= 184599
# mozilla-b2g/gaia 32133 size= 167901
# rust-lang/rust 4590 size= 43703
# zendframework/zf2 7714 size= 49248
# pydata/pandas 19009 size= 33479
# twbs/bootstrap 10584 size= 204349
# servo/servo 10082 size= 33178
# twbs/bootstrap 22985 size= 43798
# servo/servo 6243 size= 40686
# servo/servo 10929 size= 51051
# rust-lang/rust 40128 size= 46046
# twbs/bootstrap 12620 size= 1421556
# pydata/pandas 17875 size= 33666
# scikit-learn/scikit-learn 1769 size= 39871
# rust-lang/rust 19216 size= 72013
# 26000
# servo/servo 16990 size= 39222
# zendframework/zf2 1750 size= 37047
# scikit-learn/scikit-learn 3898 size= 91191
# twbs/bootstrap 9966 size= 624100
# mozilla-b2g/gaia 31695 size= 46824
# servo/servo 19499 size= 1149121
# rust-lang/rust 29648 size= 36858
# servo/servo 18117 size= 32468
# servo/servo 19499 size= 1149121
# twbs/bootstrap 13542 size= 1860728
# servo/servo 1770 size= 38466
# nodejs/node 10544 size= 35700
# twbs/bootstrap 12813 size= 3227265
# scikit-learn/scikit-learn 9078 size= 32083
# twbs/bootstrap 4447 size= 32891
# rust-lang/rust 49972 size= 117345
# saltstack/salt 43019 size= 65351
# mozilla-b2g/gaia 3742 size= 38509
# servo/servo 1327 size= 86097
# scikit-learn/scikit-learn 5141 size= 33442
# pydata/pandas 9814 size= 31909
# kubernetes/kubernetes 18215 size= 32637
# servo/servo 16934 size= 103152
# servo/servo 19254 size= 41007
# scikit-learn/scikit-learn 396 size= 37394
# pydata/pandas 14184 size= 37509
# symfony/symfony-docs 389 size= 53560
# rust-lang/rust 36729 size= 36797
# twbs/bootstrap 13867 size= 64248
# twbs/bootstrap 22985 size= 43798
# twbs/bootstrap 13594 size= 77831
# 27000
# pydata/pandas 19829 size= 76592
# twbs/bootstrap 11107 size= 383148
# twbs/bootstrap 10013 size= 197027
# twbs/bootstrap 11817 size= 203439
# zendframework/zf2 2312 size= 81588
# rust-lang/rust 51917 size= 108113
# twbs/bootstrap 3996 size= 54798
# pydata/pandas 19660 size= 31679
# pydata/pandas 15708 size= 33634
# servo/servo 18170 size= 35094
# pydata/pandas 18931 size= 75475
# servo/servo 16970 size= 44776
# mozilla-b2g/gaia 18730 size= 31018
# kubernetes/kubernetes 53240 size= 33735
# pydata/pandas 18931 size= 75475
# pydata/pandas 7036 size= 51470
# twbs/bootstrap 14563 size= 3393795
# symfony/symfony-docs 8721 size= 49791
# twbs/bootstrap 12690 size= 1597849
# pydata/pandas 17342 size= 53860
# scikit-learn/scikit-learn 4698 size= 39238
# kubernetes/kubernetes 5399 size= 59750
# servo/servo 19488 size= 1264489
# pydata/pandas 19794 size= 47719
# servo/servo 17269 size= 37214
# zendframework/zf2 2319 size= 52646
# rust-lang/rust 12238 size= 31839
# saltstack/salt 39372 size= 72093
# saltstack/salt 44405 size= 39773
# kubernetes/kubernetes 52014 size= 41788
# twbs/bootstrap 10951 size= 202035
# pydata/pandas 15708 size= 33634
# kubernetes/kubernetes 30521 size= 53052
# servo/servo 8639 size= 38256
# scikit-learn/scikit-learn 707 size= 36324
# 28000
# pydata/pandas 9130 size= 34909
# rust-lang/rust 49029 size= 31475
# saltstack/salt 10229 size= 38933
# servo/servo 11972 size= 35418
# rust-lang/rust 49972 size= 117345
# servo/servo 19376 size= 869839
# twbs/bootstrap 12633 size= 1426810
# twbs/bootstrap 8582 size= 167597
# saltstack/salt 31839 size= 38517
# twbs/bootstrap 10265 size= 199481
# twbs/bootstrap 11694 size= 625862
# kubernetes/kubernetes 31922 size= 35775
# rust-lang/rust 15238 size= 38555
# twbs/bootstrap 14563 size= 3393795
# twbs/bootstrap 8611 size= 164637
# mozilla-b2g/gaia 26736 size= 31283
# pydata/pandas 19659 size= 33472
# kubernetes/kubernetes 13487 size= 37803
# twbs/bootstrap 14563 size= 3393795
# twbs/bootstrap 11107 size= 383148
# pydata/pandas 18428 size= 50691
# symfony/symfony-docs 1295 size= 56181
# pydata/pandas 11469 size= 68245
# zendframework/zf2 7714 size= 49248
# 29000
# scikit-learn/scikit-learn 2363 size= 94242
# servo/servo 539 size= 32543
# symfony/symfony-docs 9517 size= 193206
# twbs/bootstrap 11127 size= 205194
# kubernetes/kubernetes 3004 size= 34199
# pydata/pandas 11462 size= 31283
# kubernetes/kubernetes 61515 size= 30824
# symfony/symfony-docs 1295 size= 56181
# mozilla-b2g/gaia 30680 size= 41166
# twbs/bootstrap 15491 size= 110823
# servo/servo 16994 size= 46725
# kubernetes/kubernetes 11258 size= 46375
# kubernetes/kubernetes 52656 size= 35657
# twbs/bootstrap 12813 size= 3227265
# servo/servo 1327 size= 86097
# symfony/symfony-docs 3190 size= 59764
# zendframework/zf2 1750 size= 37047
# servo/servo 20396 size= 58601
# twbs/bootstrap 12286 size= 714489
# twbs/bootstrap 8582 size= 167597
# 30000
# zendframework/zf2 3709 size= 40380
# pydata/pandas 6262 size= 33745
# servo/servo 15480 size= 44679
# twbs/bootstrap 13463 size= 44301
# kubernetes/kubernetes 52067 size= 40810
# rust-lang/rust 10519 size= 31069
# kubernetes/kubernetes 31922 size= 35775
# scikit-learn/scikit-learn 4505 size= 43677
# nodejs/node 10544 size= 35700
# mozilla-b2g/gaia 22821 size= 55753
# servo/servo 1712 size= 43185
# rust-lang/rust 1349 size= 48268
# pydata/pandas 18307 size= 41409
# scikit-learn/scikit-learn 574 size= 99967
# scikit-learn/scikit-learn 6743 size= 45526
# scikit-learn/scikit-learn 8478 size= 41285
# rust-lang/rust 46523 size= 34042
# kubernetes/kubernetes 5369 size= 31601
# rust-lang/rust 7835 size= 33383
# servo/servo 6243 size= 40686
# symfony/symfony-docs 1295 size= 56181
# pydata/pandas 9797 size= 41429
# symfony/symfony-docs 4779 size= 47697
# twbs/bootstrap 12215 size= 1238979
# rust-lang/rust 51958 size= 59512
# twbs/bootstrap 11868 size= 203385
# pydata/pandas 6987 size= 36885
# scikit-learn/scikit-learn 6913 size= 34586
# 31000
# mozilla-b2g/gaia 11430 size= 57800
# saltstack/salt 13017 size= 44172
# twbs/bootstrap 14847 size= 34479
# rust-lang/rust 41307 size= 120534
# scikit-learn/scikit-learn 6913 size= 34586
# saltstack/salt 22556 size= 54428
# pydata/pandas 19794 size= 47719
# scikit-learn/scikit-learn 5303 size= 76000
# symfony/symfony-docs 5386 size= 74064
# zendframework/zf2 3709 size= 40380
# pydata/pandas 17077 size= 36324
# twbs/bootstrap 12993 size= 2440358
# saltstack/salt 45786 size= 37356
# twbs/bootstrap 10265 size= 199481
# mozilla-b2g/gaia 8054 size= 70620
# twbs/bootstrap 10565 size= 203969
# mozilla-b2g/gaia 218 size= 47388
# mozilla-b2g/gaia 15278 size= 58393
# scikit-learn/scikit-learn 6913 size= 34586
# symfony/symfony-docs 9517 size= 193206
# kubernetes/kubernetes 54316 size= 57754
# twbs/bootstrap 10013 size= 197027
# rust-lang/rust 22984 size= 46906
# pydata/pandas 3762 size= 31678
# twbs/bootstrap 17373 size= 120234
# servo/servo 6580 size= 38702
# servo/servo 12965 size= 69857
# 32000
# kubernetes/kubernetes 28511 size= 35334
# symfony/symfony 24447 size= 36868
# nodejs/node 1760 size= 50991
# scikit-learn/scikit-learn 6667 size= 34822
# servo/servo 17147 size= 35563
# servo/servo 19376 size= 869839
# rust-lang/rust 50798 size= 44061
# scikit-learn/scikit-learn 6913 size= 34586
# scikit-learn/scikit-learn 3898 size= 91191
# kubernetes/kubernetes 5192 size= 52423
# pydata/pandas 20979 size= 36411
# twbs/bootstrap 11514 size= 207029
# pydata/pandas 19848 size= 56558
# servo/servo 18117 size= 32468
# kubernetes/kubernetes 481 size= 33588
# servo/servo 19973 size= 77933
# scikit-learn/scikit-learn 5141 size= 33442
# servo/servo 4729 size= 35861
# nodejs/node 10746 size= 49869
# symfony/symfony-docs 4779 size= 47697
# twbs/bootstrap 14444 size= 3383513
# kubernetes/kubernetes 44494 size= 38347
# twbs/bootstrap 18807 size= 35134
# kubernetes/kubernetes 63232 size= 50072
# twbs/bootstrap 13594 size= 77831
# servo/servo 10082 size= 33178
# pydata/pandas 17691 size= 32587
# servo/servo 1712 size= 43185
# twbs/bootstrap 10013 size= 197027
# 33000
# symfony/symfony 21690 size= 35811
# scikit-learn/scikit-learn 5560 size= 175623
# servo/servo 11724 size= 47773
# servo/servo 12294 size= 40969
# scikit-learn/scikit-learn 9252 size= 58975
# pydata/pandas 5336 size= 47218
# twbs/bootstrap 11086 size= 205041
# pydata/pandas 15451 size= 32867
# twbs/bootstrap 13867 size= 64248
# saltstack/salt 23325 size= 31910
# twbs/bootstrap 13768 size= 41950
# twbs/bootstrap 12813 size= 3227265
# servo/servo 19255 size= 294822
# symfony/symfony-docs 8599 size= 37495
# servo/servo 13898 size= 92515
# kubernetes/kubernetes 38110 size= 34605
# mozilla-b2g/gaia 11430 size= 57800
# scikit-learn/scikit-learn 868 size= 39178
# rust-lang/rust 4251 size= 31709
# servo/servo 19368 size= 1419643
# pydata/pandas 6262 size= 33745
# servo/servo 542 size= 31795
# pydata/pandas 9493 size= 34715
# twbs/bootstrap 699 size= 34699
# twbs/bootstrap 10079 size= 196630
# pydata/pandas 20347 size= 34380
# mozilla-b2g/gaia 15052 size= 55801
# mozilla-b2g/gaia 8389 size= 30877
# kubernetes/kubernetes 4963 size= 292914
# 34000
# twbs/bootstrap 10565 size= 203969
# kubernetes/kubernetes 61329 size= 35919
# scikit-learn/scikit-learn 10700 size= 40726
# servo/servo 6243 size= 40686
# pydata/pandas 13767 size= 36272
# pydata/pandas 20979 size= 36411
# servo/servo 1770 size= 38466
# saltstack/salt 43681 size= 31649
# kubernetes/kubernetes 38348 size= 49398
# servo/servo 14999 size= 55277
# twbs/bootstrap 11138 size= 590839
# scikit-learn/scikit-learn 396 size= 37394
# twbs/bootstrap 11086 size= 205041
# pydata/pandas 9813 size= 70663
# twbs/bootstrap 10951 size= 202035
# servo/servo 15039 size= 33627
# symfony/symfony-docs 8599 size= 37495
# twbs/bootstrap 12773 size= 81673
# scikit-learn/scikit-learn 3611 size= 49585
# scikit-learn/scikit-learn 2790 size= 155357
# pydata/pandas 18346 size= 37010
# twbs/bootstrap 10232 size= 594602
# nodejs/node 10544 size= 35700
# 35000
# pydata/pandas 4333 size= 50946
# pydata/pandas 10507 size= 39164
# twbs/bootstrap 11956 size= 691121
# symfony/symfony-docs 4313 size= 34086
# pydata/pandas 19661 size= 34846
# twbs/bootstrap 10013 size= 197027
# nodejs/node 10544 size= 35700
# twbs/bootstrap 5549 size= 55042
# scikit-learn/scikit-learn 707 size= 36324
# symfony/symfony-docs 8721 size= 49791
# rust-lang/rust 16883 size= 33259
# symfony/symfony-docs 809 size= 31386
# symfony/symfony-docs 4779 size= 47697
# twbs/bootstrap 12655 size= 35664
# mozilla-b2g/gaia 13876 size= 59707
# nodejs/node 1760 size= 50991
# rust-lang/rust 40297 size= 36960
# kubernetes/kubernetes 4031 size= 57477
# zendframework/zf2 2312 size= 81588
# twbs/bootstrap 9966 size= 624100
# 36000
# pydata/pandas 9814 size= 31909
# mozilla-b2g/gaia 15792 size= 50477
# symfony/symfony 16915 size= 40175
# servo/servo 13682 size= 44326
# rust-lang/rust 12321 size= 37317
# mozilla-b2g/gaia 26218 size= 34798
# servo/servo 14999 size= 55277
# twbs/bootstrap 11750 size= 263396
# saltstack/salt 28599 size= 34711
# servo/servo 18800 size= 78576
# twbs/bootstrap 14444 size= 3383513
# twbs/bootstrap 25020 size= 30893
# pydata/pandas 7599 size= 43165
# twbs/bootstrap 14564 size= 993193
# pydata/pandas 18428 size= 50691
# servo/servo 3819 size= 38430
# twbs/bootstrap 25820 size= 117345
# scikit-learn/scikit-learn 2700 size= 57144
# twbs/bootstrap 11186 size= 205582
# rust-lang/rust 41112 size= 37212
# kubernetes/kubernetes 4816 size= 293131
# pydata/pandas 6937 size= 78539
# mozilla-b2g/gaia 26274 size= 39221
# twbs/bootstrap 11930 size= 34706
# symfony/symfony-docs 5083 size= 32151
# 37000
# twbs/bootstrap 10079 size= 196630
# symfony/symfony-docs 3190 size= 59764
# pydata/pandas 7926 size= 47006
# saltstack/salt 39080 size= 83215
# twbs/bootstrap 13793 size= 98189
# pydata/pandas 9321 size= 45801
# scikit-learn/scikit-learn 1884 size= 41132
# symfony/symfony-docs 809 size= 31386
# twbs/bootstrap 13542 size= 1860728
# scikit-learn/scikit-learn 2631 size= 236087
# zendframework/zf2 3709 size= 40380
# zendframework/zf2 2319 size= 52646
# saltstack/salt 31386 size= 35863
# twbs/bootstrap 12688 size= 1069215
# pydata/pandas 18721 size= 63061
# nodejs/node 13707 size= 34011
# scikit-learn/scikit-learn 3611 size= 49585
# pydata/pandas 19794 size= 47719
# twbs/bootstrap 16384 size= 2578413
# scikit-learn/scikit-learn 1263 size= 139185
# rust-lang/rust 9556 size= 40882
# saltstack/salt 28486 size= 45619
# saltstack/salt 39080 size= 83215
# kubernetes/kubernetes 912 size= 60339
# kubernetes/kubernetes 30832 size= 34198
# zendframework/zf2 4268 size= 35402
# twbs/bootstrap 11697 size= 205102
# kubernetes/kubernetes 54752 size= 36544
# mozilla-b2g/gaia 15004 size= 50564
# servo/servo 19618 size= 1343650
# pydata/pandas 14184 size= 37509
# scikit-learn/scikit-learn 6697 size= 43099
# kubernetes/kubernetes 36732 size= 82961
# servo/servo 19141 size= 40550
# 38000
# twbs/bootstrap 12993 size= 2440358
# servo/servo 13061 size= 54716
# servo/servo 539 size= 32543
# twbs/bootstrap 12696 size= 75631
# rust-lang/rust 20082 size= 36976
# mozilla-b2g/gaia 18003 size= 49598
# pydata/pandas 6937 size= 78539
# kubernetes/kubernetes 55970 size= 31215
# pydata/pandas 14295 size= 33044
# scikit-learn/scikit-learn 4570 size= 91786
# servo/servo 557 size= 47696
# scikit-learn/scikit-learn 6697 size= 43099
# twbs/bootstrap 3996 size= 54798
# mozilla-b2g/gaia 14138 size= 134570
# kubernetes/kubernetes 33451 size= 51088
# mozilla-b2g/gaia 4502 size= 40985
# servo/servo 11866 size= 31646
# twbs/bootstrap 12773 size= 81673
# scikit-learn/scikit-learn 9041 size= 32548
# scikit-learn/scikit-learn 2488 size= 41139
# kubernetes/kubernetes 35008 size= 58958
# pydata/pandas 9814 size= 31909
# twbs/bootstrap 12655 size= 35664
# kubernetes/kubernetes 42974 size= 31166
# scikit-learn/scikit-learn 6667 size= 34822
# pydata/pandas 7599 size= 43165
# twbs/bootstrap 1153 size= 46025
# 39000
# pydata/pandas 8586 size= 53602
# pydata/pandas 7926 size= 47006
# servo/servo 1712 size= 43185
# twbs/bootstrap 24610 size= 37051
# mozilla-b2g/gaia 29103 size= 31457
# kubernetes/kubernetes 56445 size= 677015
# scikit-learn/scikit-learn 2931 size= 84729
# pydata/pandas 9130 size= 34909
# nodejs/node 10746 size= 49869
# mozilla-b2g/gaia 28430 size= 48040
# twbs/bootstrap 11750 size= 263396
# servo/servo 2751 size= 32457
# scikit-learn/scikit-learn 9041 size= 32548
# servo/servo 19660 size= 1463224
# servo/servo 12643 size= 58374
# saltstack/salt 31839 size= 38517
# twbs/bootstrap 22921 size= 54139
# pydata/pandas 3103 size= 43918
# mozilla-b2g/gaia 12838 size= 114044
# twbs/bootstrap 11750 size= 263396
# kubernetes/kubernetes 4693 size= 40673
# servo/servo 19380 size= 747643
# twbs/bootstrap 12993 size= 2440358
# saltstack/salt 47243 size= 58747
# servo/servo 14999 size= 55277
# kubernetes/kubernetes 4486 size= 40645
# servo/servo 7611 size= 34017
# twbs/bootstrap 11928 size= 498031
# 40000
# zendframework/zf2 3709 size= 40380
# scikit-learn/scikit-learn 1263 size= 139185
# kubernetes/kubernetes 63213 size= 33787
# pydata/pandas 5405 size= 36096
# twbs/bootstrap 11804 size= 286265
# symfony/symfony-docs 4313 size= 34086
# rust-lang/rust 50798 size= 44061
# rust-lang/rust 9263 size= 32971
# scikit-learn/scikit-learn 3035 size= 57606
# mozilla-b2g/gaia 24306 size= 39006
# servo/servo 13898 size= 92515
# scikit-learn/scikit-learn 2460 size= 56350
# rust-lang/rust 41112 size= 37212
# zendframework/zf2 7474 size= 31205
# zendframework/zf2 4268 size= 35402
