# %%
from git import *
from comp import *
from clf import *
#p1=get_pull('laravel/framework','4138')
#p2=get_pull('laravel/framework','2678')

#s = 'facebook/react 3969 3807'

#s = 'facebook/react 12488	10255'

#s = 'facebook/react 11868	4426'

#s='facebook/react	12770	12311'

# s = 'elastic/elasticsearch 27744 27600'

# s = 'CleverRaven/Cataclysm-DDA 10005 8445'

# s = 'Homebrew/homebrew-cask	48598	35654'

# s = 'kubernetes/kubernetes 50018 55744'

s = 'facebook/react 3663 3508'

repo, n1, n2 = s.split()

init_model_with_repo(repo)

p1=get_pull(repo, n1)
p2=get_pull(repo, n2)

if check_too_big(p1) or check_too_big(p2):
    print('too big!')

#print(fetch_pr_info(p1))
#print(fetch_pr_info(p2))

# print(get_numbers(p1['body']), get_numbers(p2['body']))
print(get_pr_sim(p1,p2))
print(get_file_list(p1))
print(get_file_list(p2))


'''
print(p1['body'])
print(p2['body'])

A=p1
print(get_version_numbers(A["title"] + ' ' + A['body']))
   
A=p2
print(get_version_numbers(A["title"] + ' ' + A['body']))
'''

vet = get_pr_sim(p1,p2)

print(vet)

'''

c = classify()
ret = c.predict_proba([get_pr_sim_vector(p1,p2)])[0][1]

print(ret)
'''
# Out:
# init nlp model with facebook/react data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# {'title': [0.05257318742759109], 'desc': [0.13886693689185015], 'code': [0.0, 0.0], 'file_list': [0, 0], 'location': [0.0, 0.0], 'pattern': [1]}
# []
# ['docs/index.md']
# {'title': [0.05257318742759109], 'desc': [0.13886693689185015], 'code': [0.0, 0.0], 'file_list': [0, 0], 'location': [0.0, 0.0], 'pattern': [1]}
# '\n\nc = classify()\nret = c.predict_proba([get_pr_sim_vector(p1,p2)])[0][1]\n\nprint(ret)\n'

# %%
import simulate_part_pr



s = 'angular/angular.js	8492	8233'
repo, n1, n2 = s.split()

init_model_with_repo(repo)

simulate_part_pr.simulate(repo, n1, n2)

# %%
from detect import *

print(get_topK('facebook/react', '3663', 10, True))
# Out:
# init nlp model with facebook/react data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# progress =  0.7165376898824878
# progress =  0.7308684436801376
# progress =  0.7451991974777873
# progress =  0.7595299512754371
# progress =  0.7738607050730868
# progress =  0.8025222126683863
# progress =  0.8168529664660361
# progress =  0.8311837202636859
# progress =  0.8455144740613356
# progress =  0.8598452278589854
# progress =  0.8741759816566351
# progress =  0.8885067354542849
# progress =  0.9028374892519346
# progress =  0.9171682430495844
# progress =  0.9314989968472341
# progress =  0.945829750644884
# progress =  0.9601605044425336
# progress =  0.9744912582401835
# [(3572, 0.4685700293477373), (3217, 0.4600980231019911), (6, 0.4600980231019911), (3152, 0.45804204593242653), (714, 0.45804204593242653), (2475, 0.4534534170385415), (1888, 0.44903559176562363), (1155, 0.4476900425157769), (3508, 0.44749082997181316), (3190, 0.44554667458724195)]

# %%
from git import *

repos = open('data/msr_repo_list.txt').readlines()

# repo = 'cocos2d/cocos2d-x'

for repo in repos:

    pulls = get_pull_list(repo, False)

    num, tot = 0, 0
    for pull in pulls:
        tot += 1
        if len(get_pr_numbers(str(pull['title']) + str(pull['body']))) > 0:
            num += 1
    print(repo.strip(), ':', 1.0 * num / tot)

# %%
from main import *

# init_model_with_repo('Ultimaker/Ultimaker2Marlin')
init_model_with_repo('MarlinFirmware/Marlin')
get_sim_vector(get_pull('Ultimaker/Ultimaker2Marlin', '50'), get_pull('MarlinFirmware/Marlin', '1402'))

# %%
from main import *

# init_model_with_repo('ceph/ceph')

p1 = get_pull('hashicorp/terraform', '6827')
t = get_another_pull(p1)
print(type(t[0]))
print(get_another_pull(p1))

print(type(p1["number"]))
'''
p2 = get_pull('ceph/ceph', '10427')
print(get_BoW(p1["title"]))
print(get_BoW(p2["title"]))

print(get_sim('ceph/ceph', '10438', '10427'))

print(check_pattern(p1, p2))
'''

# %%
from main import *

# init_model_with_repo('Ultimaker/Ultimaker2Marlin')
init_model_with_repo('MarlinFirmware/Marlin')
get_sim_vector(get_pull('Ultimaker/Ultimaker2Marlin', '50'), get_pull('MarlinFirmware/Marlin', '1402'))

# %%
from main import *

# init_model_with_repo('Ultimaker/Ultimaker2Marlin')
init_model_with_repo('MarlinFirmware/Marlin')
get_pr_sim_vector(get_pull('Ultimaker/Ultimaker2Marlin', '50'), get_pull('MarlinFirmware/Marlin', '1402'))

# %%
import main
# main.init_model_with_repo('facebook/react')
# main.get_sim('facebook/react', '12767', '11770')

main.init_model_with_repo('facebook/react')
main.get_sim('facebook/react', '466', '433')

# %%
import main
main.init_model_with_repo('facebook/react')
main.get_sim('facebook/react', '12767', '11770')

# %%
import main
import git

# %time main.init_model_with_pulls(git.get_pull_list('MarlinFirmware/Marlin'))

'''
import main
main.init_model_with_repo('SignalR/SignalR')
main.get_sim('SignalR/SignalR', '3094', '3862')
'''

# %%
import re
def camel_case_split(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return [m.group(0) for m in matches]

print(camel_case_split('AasAdsaB'))
print(camel_case_split('dasAdsaBcdas'))
print(camel_case_split('ARM64'))

print(camel_case_split('321jca+dsad321_dsaAz'))

# %%
import main
c = main.classify() # all

"""
with open('tmp/1.txt') as f:
    for l in f.readlines():
        if len(l)<=3:
            continue
        p, n1, n2 = l.split()
        
        t = main.get_sim(p, n1, n2)
        
        print(c.predict([t])[0], p, n1, n2, t)
"""

with open('')
X_test = localfile_tool.get_file('data/improve_false_data_msr_positive_pairs_lsi_X.json')
y_test = localfile_tool.get_file('data/improve_false_data_msr_positive_pairs_lsi_y.json')

acc = c.score(X_test, y_test)
print('Mean Accuracy:', acc)

# c.predict()

# %%
import main
main.get_sim('mozilla-b2g/gaia', '2420', '2459')

# %%
import main
p = main.get_pull('mozilla-b2g/gaia', '2420')
f = fetch_pr_info(p)
print([x["name"] for x in f])

# %%
from main import *
from git import *
from comparer import *

repo = 'spring-projects/spring-framework'
init_model_with_pulls([], repo.replace('/','_') + '_all')
# init_model_with_repo(repo)

x = 'Changed min accepted day of month to 1'
y = 'Support for the last day in month cron expression'

'''
x = 'Tokenizer - removing unnecessary boxing'
y = 'Tokenizer - removes unnecessary boxing of char'
'''

# %timeit text_sim(x,y)
# text_sim(x,y)
'''
print(model.get_tfidf(get_BoW(x)))
print(model.get_tfidf(get_BoW(y)))
c = set(get_BoW(x)) & set(get_BoW(y))
print(model.get_idf_sum(c))
'''

# %%
from util import localfile
ps = localfile.get_file('data/msr_positive_pairs_feature_vector_all_clues_with_text_lsi_code_bow_X.json')
for p in ps:
    if p[0] >= 0.9:
        print(p[0], p[2])

# %%
from git import *
from comp import *

def func(file):

    num = 0
    tot = 0
    with open(file) as f:
        for f0 in f.readlines():
            r, n1, n2 = f0.split()
            p1 = get_pull(r, n1)
            p2 = get_pull(r, n2)
            s1 = get_tokens(p1['title'])
            s2 = get_tokens(p2['title'])
            if (set(s1) & set(s2)):
                t = len(s1) + len(s1)
                num += 1
                tot += t

    print (1.0 * tot / num)
    
func('data/clf/small_part_negative.txt')
func('data/clf/msr_positive_pairs.txt')

                                    
'''                      
with open('data/clf/manual_label_false.txt') as f:
    for t in f.readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        t = set(get_tokens(p1['title'])) & set(get_tokens(p2['title']))
        if t:
            print(t)
'''

# %%
from git import *
from comp import *

r = 'laravel/framework'

ps = get_repo_info(r, 'pull')
tot = 0
cnt = 0
for p in ps:
    cnt += 1
    print(cnt)

    file_list = fetch_pr_info(p)
    for file in file_list:
        tot += len(file["add_code"]) + len(file["del_code"])

print('tot=', tot)

# %%
from numpy import array
from numpy import median
from clf import *


def q(a):
    print('\t'.join(['{0:0.4f}'.format(1.0 * sum(a[:,i]) / len(a)) for i in range(len(a[0]))]))
    
    # print('\t'.join(['{0:0.4f}'.format(median(a[:,i])) for i in range(len(a[0]))]))
    
f = []
no = []
yes = []
for s in dataset:
    new_X, new_y = get_feature_vector(s[0], s[1], model_data_renew_flag, model_data_save_path_suffix)
    
    if ('true' in s[0]) or ('msr' in s[0]):
        yes += new_X
    else:
        no += new_X

no = array(no)
yes = array(yes)

# q(no)
# q(yes)


# sum(L) / float(len(L))

# %%
from clf import *
from comp import *

last = None
q = []

cnt = {}

with open('/home/luyao/PR_get/INTRUDE/data/clf/manual_label_true.txt') as f:
    for pair in f.readlines():
        r, n1, n2 = pair.split()
        
        if r != last:
            last = r
            # init_model_with_repo(r)
            print('cnt', r)
            cnt = {}
            ps = get_repo_info(r, 'pull')
            for p in ps:
                for x in get_tokens(p['title']):
                    if x not in cnt:
                        cnt[x] = 0
                    cnt[x] += 1
        
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        def add(p):
            x = [cnt.get(word, 0) for word in get_tokens(p['title'])]
            q.append(sum(x) / len(x))
            
        add(p1)
        add(p2)

print(sum(q) / len(q))

# %%
from clf import *
from comp import *

init_model_with_repo('bitcoin/bitcoin')
p1 = get_pull('peercoin/peercoin', '219')
p2 = get_pull('bitcoin/bitcoin', '5509')

print(get_pr_sim_vector(p1, p2))

# %%
files = [
'/home/luyao/PR_get/INTRUDE/data/clf/manual_label_false.txt',
#'/home/luyao/PR_get/INTRUDE/data/clf/manual_label_true.txt',
'/home/luyao/PR_get/INTRUDE/data/clf/openpr_label_false.txt',
#'/home/luyao/PR_get/INTRUDE/data/clf/openpr_label_true.txt'
]

for file in files:
    for t in open(file).readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        def add(p1):
            file_list = fetch_pr_info(p1)
            return sum([x["LOC"]['add'] for x in file_list])
        def dele(p1):
            file_list = fetch_pr_info(p1)
            return sum([x["LOC"]['del'] for x in file_list])
        
        
        print(t.strip(), 'line=', '+%d,-%d' % (add(p1), dele(p1)) , '\t', '+%d,-%d' % (add(p2), dele(p2)))
        print(p1['title'])
        print(p2['title'])
        
        print('------')
    
        '''
        file_list = fetch_pr_info(p1)
        if len(file_list) <= 10:
            #print(p1['title'], ':', [x['name'] for x in file_list])
            t = sum([x["LOC"]['add'] for x in file_list])
            if t <= 10:
                print(r, n1, n2, p1['title'], ':', t)
        '''

# %%
files = [
    '/home/luyao/PR_get/INTRUDE/data/clf/small_part_msr.txt',
    '/home/luyao/PR_get/INTRUDE/data/clf/rly_false_pairs.txt'
]

from datetime import datetime, timedelta

def get_time(t):
    return datetime.strptime(t, "%Y-%m-%dT%H:%M:%SZ")

from git import *

for file in files:
    q = []
    for t in open(file).readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        d = abs((get_time(p1['created_at']) - get_time(p2['created_at'])).days)
        q.append(d)

    print(sum(q) / len(q))
    print(sorted(q))

# %%
from git import *
# % timeit t = get_pull(, )

% timeit t = api.get('repos/%s/pulls/%s' % ('facebook/react', '12391'))

print(t)

# %%
from detect import *
print(get_topK('laravel/framework', '22057', 10, True))
# Out:
# text_sim_type= lsi
# code_sim_type= tfidf
# extract_sim_type= ori_and_overlap
# Data Type: ok_text_lsi_code_tfidf_ori_and_overlap
# Data Loading.........
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_nondup.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/first_nondup_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_nondup.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/second_nondup_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# --------------------------
# Model: training_set 50618 testing_set 50737 feature_length= 9
# ------ model:  boost ------
# [0.22  0.42  0.105 0.005 0.05  0.045 0.035 0.055 0.065]
# Mean Accuracy: 0.9942645406705166
# Average precision score: 0.9191
# F1 score: 0.8643
# init nlp model with laravel/framework data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# progress =  0.1305293691080493
# progress =  0.22480058013052936
# progress =  0.39158810732414795
# progress =  0.43509789702683105
# progress =  0.580130529369108
# progress =  0.6816533720087019
# progress =  0.7034082668600435
# progress =  0.7831762146482959
# [(16655, 0.6029130227943807), (16018, 0.6029130227943807), (15593, 0.5880381771736395), (17451, 0.5747332692442766), (15661, 0.5547340525839011), (16170, 0.5314063964295124), (16867, 0.5218326721905272), (14710, 0.48754458267015777), (13817, 0.48754458267015777), (19708, 0.48504067368337705)]

# %%
from git import *
from comp import *
from clf import *

s = 'laravel/framework 18705 17589'

repo, n1, n2 = s.split()

init_model_with_repo(repo)

p1=get_pull(repo, n1)
p2=get_pull(repo, n2)

vet = get_pr_sim(p1,p2)

print(vet)

c = classify()
ret = c.predict_proba([get_pr_sim_vector(p1,p2)])[0][1]

print(ret)
# Out:
# init nlp model with laravel/framework data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# {'title': [0.8746197528924626], 'desc': [0.0], 'code': [0.6404730300257933, 0.6404730300257933], 'file_list': [1.0, 1], 'location': [0.0, 0.0], 'pattern': [0]}
# Data Loading.........
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_nondup.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/first_nondup_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_nondup.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/second_nondup_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# --------------------------
# Model: training_set 50618 testing_set 50737 feature_length= 9
# ------ model:  boost ------
# [0.22  0.42  0.105 0.005 0.045 0.05  0.035 0.055 0.065]
# Mean Accuracy: 0.9942645406705166
# Average precision score: 0.9191
# F1 score: 0.8643
# 0.5601423492316505

# %%
from git import *
from detect import *
		

p1=get_pull('angular/angular.js', '13349')
p2=get_pull('angular/angular.js', '13347')
print(have_commit_overlap(p1, p2))
# Out:
# False

# %%
from git import *
from detect import *

print(get_topK('angular/angular.js', '13349'))
# Out:
# text_sim_type= lsi
# code_sim_type= tfidf
# extract_sim_type= ori_and_overlap
# Data Type: ok_text_lsi_code_tfidf_ori_and_overlap
# Data Loading.........
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_nondup.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/first_nondup_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_nondup.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/second_nondup_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# --------------------------
# Model: training_set 50618 testing_set 50737 feature_length= 9
# ------ model:  boost ------
# [0.22  0.42  0.105 0.005 0.06  0.035 0.045 0.045 0.065]
# Mean Accuracy: 0.9942645406705166
# Average precision score: 0.9191
# F1 score: 0.8643
# init nlp model with angular/angular.js data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# finish write /DATA/luyao/pr_data/angular/angular.js/13160/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13150/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13140/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13124/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13114/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13113/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13110/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13099/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13059/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13028/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13025/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13020/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13018/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13007/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13002/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/13000/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12999/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12995/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12991/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12987/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12986/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12979/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12972/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12930/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12921/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12889/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12881/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12871/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12862/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12850/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12843/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12839/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12832/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12831/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12829/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12799/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12790/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12781/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12774/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12746/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12738/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12725/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12721/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12716/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12709/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12708/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12704/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12701/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12696/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12687/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12669/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12657/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12651/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12637/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12634/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12619/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12610/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12593/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12570/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12568/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12566/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12541/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12534/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12528/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12525/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12521/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12520/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12504/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12502/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12490/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12483/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12473/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12469/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12464/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12462/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12459/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12451/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12444/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12429/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12415/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12408/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12407/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12406/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12401/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12361/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12358/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12346/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12340/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12338/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12326/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12317/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12294/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12291/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12290/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12289/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12282/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12245/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12244/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12227/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12217/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12203/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12202/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12194/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12159/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12138/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12114/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12111/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12086/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12078/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12075/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12067/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12052/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12042/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12038/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/12010/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11989/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11957/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11947/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11946/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11934/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11928/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11927/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11910/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11908/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11907/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11899/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11895/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11894/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11891/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11881/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11870/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11865/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11854/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11852/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11851/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11825/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11814/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11807/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11805/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11804/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11800/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11766/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11764/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11760/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11755/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11747/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11744/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11740/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11736/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11735/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11719/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11704/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11698/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11697/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11686/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11653/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11644/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11640/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11620/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11609/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11608/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11604/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11592/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11584/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11576/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11575/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11572/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11569/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11568/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11566/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11560/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11546/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11544/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11509/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11502/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11493/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11488/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11485/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11471/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11469/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11461/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11455/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11410/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11393/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11386/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11369/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11365/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11340/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11320/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11310/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11294/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11285/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11275/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11273/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11270/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11238/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11215/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11211/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11206/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11205/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11199/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11171/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11159/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11144/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11117/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11116/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11106/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11094/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11092/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11088/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11087/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11058/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11057/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11052/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11046/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11043/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11027/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11023/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/11018/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10983/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10960/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10922/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10919/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10910/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10909/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10899/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10883/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10880/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10876/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10872/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10871/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10853/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10849/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10841/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10832/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10794/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10791/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10780/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10778/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10770/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10764/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10761/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10759/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10744/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10741/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10723/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10720/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10694/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10684/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10676/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10664/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10658/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10656/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10623/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10621/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10589/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10566/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10555/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10552/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10551/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10548/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10519/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10475/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10468/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10452/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10429/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10424/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10422/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10409/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10379/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10352/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10337/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10329/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10322/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10318/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10308/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10305/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10302/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10290/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10254/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10252/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10242/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10211/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10202/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10194/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10189/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10187/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10185/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10184/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10182/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10181/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10177/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10176/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10154/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10137/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10124/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10116/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10106/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10091/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10085/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10064/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10049/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10045/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10044/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10042/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10032/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10031/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10028/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10021/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10020/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10018/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/10017/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9979/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9957/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9950/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9945/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9942/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9938/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9914/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9906/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9899/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9898/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9874/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9873/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9871/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9834/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9800/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9799/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9795/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9775/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9770/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9765/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9753/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9751/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9747/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9745/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9730/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9729/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9724/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9722/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9720/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9712/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9690/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9679/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9653/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9632/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9622/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9617/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9616/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9615/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9589/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9580/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9569/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9568/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9560/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9558/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9556/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9551/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9550/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9544/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9512/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9503/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9499/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9498/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9494/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9493/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9488/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9483/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9477/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9475/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9468/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9458/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9445/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9424/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9423/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9419/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9415/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9406/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9403/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9402/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9393/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9392/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9385/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9382/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9349/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9322/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9320/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9313/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9310/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9302/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9300/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9287/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9283/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9257/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9240/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9165/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9157/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9135/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9123/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9117/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9102/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9099/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9089/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9077/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9074/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9070/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9069/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9060/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9058/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9046/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9045/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9024/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9023/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9017/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9016/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/9006/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8974/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8964/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8958/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8953/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8939/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8933/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8925/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8894/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8893/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8879/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8867/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8861/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8858/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8852/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8846/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8841/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8838/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8826/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8824/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8816/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8803/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8800/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8785/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8767/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8757/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8741/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8731/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8717/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8691/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8679/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8654/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8632/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8629/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8615/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8604/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8599/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8595/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8587/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8584/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8581/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8568/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8558/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8548/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8546/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8544/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8521/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8519/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8457/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8452/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8451/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8450/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8437/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8417/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8396/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8380/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8367/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8364/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8360/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8359/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8347/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8342/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8305/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8271/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8268/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8261/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8244/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8231/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8227/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8213/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8203/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8202/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8193/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8192/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8154/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8146/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8125/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8120/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8113/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8016/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8009/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8006/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/8004/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7998/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7995/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7959/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7946/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7932/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7918/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7897/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7880/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7856/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7840/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7839/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7832/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7825/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7820/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7793/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7767/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7758/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7754/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7741/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7722/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7719/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7701/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7673/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7651/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7637/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7633/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7628/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7607/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7598/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7597/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7588/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7581/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7580/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7569/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7566/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7563/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7543/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7527/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7523/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7495/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7460/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7442/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7433/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7427/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7425/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7418/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7397/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7384/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7379/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7377/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7373/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7369/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7367/commits.json to file....
# finish write /DATA/luyao/pr_data/angular/angular.js/7366/commits.json to file....
