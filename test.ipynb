# %%
from git import *
from comp import *
from clf import *


#p1=get_pull('laravel/framework','4138')
#p2=get_pull('laravel/framework','2678')

#s = 'facebook/react 3969 3807'

#s = 'facebook/react 12488	10255'

#s = 'facebook/react 11868	4426'

#s='facebook/react	12770	12311'

# s = 'elastic/elasticsearch 27744 27600'

# s = 'CleverRaven/Cataclysm-DDA 10005 8445'

# s = 'Homebrew/homebrew-cask	48598	35654'

# s = 'kubernetes/kubernetes 50018 55744'

s = 'cocos2d/cocos2d-x 3275 3276'

repo, n1, n2 = s.split()

init_model_with_repo(repo)

p1=get_pull(repo, n1)
p2=get_pull(repo, n2)

#print(fetch_pr_info(p1))
#print(fetch_pr_info(p2))

# print(get_numbers(p1['body']), get_numbers(p2['body']))
#calc_sim(p1,p2)

'''
print(p1['body'])
print(p2['body'])

A=p1
print(get_version_numbers(A["title"] + ' ' + A['body']))
   
A=p2
print(get_version_numbers(A["title"] + ' ' + A['body']))
'''

vet = get_pr_sim(p1,p2)

print(vet)


c = classify()
ret = c.predict_proba([get_pr_sim_vector(p1,p2)])[0][1]

print(ret)


#print(get_topK('elastic/elasticsearch', '6287', 10, True))

#print(get_topK('facebook/react', '3405', 10, True))
#print(get_topK('facebook/react', '1702', 10, True))
# Out:
# text_sim_type= lsi
# code_sim_type= bow
# extract_sim_type= ori_and_overlap
# Data Type: ok_text_lsi_code_bow_ori_and_overlap
# init nlp model with cocos2d/cocos2d-x data!
# model already exists!
# init nlp model for text successfully!
# {'title': [-0.0005022094503912706], 'desc': [0.0], 'code': [0.08607900444817011, 0.06198647005977224], 'file_list': [0.047619047619047616, 2], 'location': [0.02641802641802642, 0.272], 'pattern': [0]}
# Data Loading.........
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs_feature_vector_ok_text_lsi_code_bow_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs_feature_vector_ok_text_lsi_code_bow_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_nondup.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/first_nondup_feature_vector_ok_text_lsi_code_bow_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_nondup.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/second_nondup_feature_vector_ok_text_lsi_code_bow_ori_and_overlap
# --------------------------
# Model: training_set 50618 testing_set 50737 feature_length= 9
# ------ model:  boost ------
# [0.21  0.41  0.135 0.005 0.04  0.05  0.04  0.045 0.065]
# Mean Accuracy: 0.9941068648126614
# Average precision score: 0.9138
# 0.5033854219302342

# %%
import simulate_part_pr



s = 'angular/angular.js	8492	8233'
repo, n1, n2 = s.split()

init_model_with_repo(repo)

simulate_part_pr.simulate(repo, n1, n2)
# Out:
# text_sim_type= lsi
# code_sim_type= tfidf
# extract_sim_type= ori_and_overlap
# Data Type: text_lsi_code_tfidf_ori_and_overlap_add_time
# Data Loading.........
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/rly_true_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/rly_true_pairs_feature_vector_text_lsi_code_tfidf_ori_and_overlap_add_time
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/rly_false_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/rly_false_pairs_feature_vector_text_lsi_code_tfidf_ori_and_overlap_add_time
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/small_part_msr.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/small_part_msr_feature_vector_text_lsi_code_tfidf_ori_and_overlap_add_time
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/small2_part_msr.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/small2_part_msr_feature_vector_text_lsi_code_tfidf_ori_and_overlap_add_time
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/small_part_negative.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/small_part_negative_feature_vector_text_lsi_code_tfidf_ori_and_overlap_add_time
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/manual_label_false.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/manual_label_false_feature_vector_text_lsi_code_tfidf_ori_and_overlap_add_time
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/manual_label_true.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/manual_label_true_feature_vector_text_lsi_code_tfidf_ori_and_overlap_add_time
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/openpr_label_false.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/openpr_label_false_feature_vector_text_lsi_code_tfidf_ori_and_overlap_add_time
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/openpr_label_true.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/openpr_label_true_feature_vector_text_lsi_code_tfidf_ori_and_overlap_add_time
# --------------------------
# Model: training_set 4506 testing_set 283 feature_length= 10
# ------ model:  boost ------
# [0.25 0.17 0.08 0.01 0.03 0.05 0.   0.07 0.03 0.31]
# Mean Accuracy: 0.43462897526501765
# Average precision score: 0.5827
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f3b856a74660> in <module>()
#       6 repo, n1, n2 = s.split()
#       7
# ----> 8 init_model_with_repo(repo)
#       9
#      10 simulate_part_pr.simulate(repo, n1, n2)
#
# NameError: name 'init_model_with_repo' is not defined

# %%
from detect import *
 

print(get_topK('symfony/symfony', '10425', 10, True))
# Out:
# text_sim_type= lsi
# code_sim_type= tfidf
# extract_sim_type= ori_and_overlap
# Data Type: text_lsi_code_tfidf_ori_and_overlap
# Data Loading.........
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/rly_true_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/rly_true_pairs_feature_vector_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/rly_false_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/rly_false_pairs_feature_vector_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/small_part_msr.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/small_part_msr_feature_vector_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/small2_part_msr.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/small2_part_msr_feature_vector_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/small_part_negative.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/small_part_negative_feature_vector_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/manual_label_false.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/manual_label_false_feature_vector_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/manual_label_true.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/manual_label_true_feature_vector_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/openpr_label_false.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/openpr_label_false_feature_vector_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/openpr_label_true.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/openpr_label_true_feature_vector_text_lsi_code_tfidf_ori_and_overlap
# --------------------------
# Model: training_set 4506 testing_set 283 feature_length= 9
# ------ model:  boost ------
# [0.25  0.44  0.095 0.015 0.055 0.025 0.02  0.045 0.055]
# Mean Accuracy: 0.4169611307420495
# Average precision score: 0.5789
# init nlp model with symfony/symfony data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# progress =  0.6028368794326241
# progress =  0.6087470449172577
# progress =  0.6146572104018913
# progress =  0.6323877068557919
# progress =  0.6382978723404256
# progress =  0.6619385342789598
# progress =  0.6678486997635934
# progress =  0.6737588652482269
# progress =  0.6796690307328606
# progress =  0.6973995271867612
# progress =  0.7151300236406619
# progress =  0.7387706855791962
# progress =  0.7624113475177305
# progress =  0.7683215130023641
# progress =  0.7742316784869976
# progress =  0.8037825059101655
# progress =  0.8274231678486997
# progress =  0.8333333333333334
# progress =  0.8451536643026005
# progress =  0.8628841607565012
# progress =  0.8687943262411347
# progress =  0.8747044917257684
# progress =  0.8865248226950354
# progress =  0.892434988179669
# progress =  0.8983451536643026
# progress =  0.9042553191489362
# progress =  0.9692671394799054
# progress =  0.975177304964539
# progress =  0.9869976359338062
# [(10030, 0.628884247607066), (9726, 0.6163093662600535), (9452, 0.585780779872855), (6421, 0.5817358147203545), (8801, 0.5750317412706587), (10153, 0.5704568072344784), (5575, 0.5704568072344784), (5456, 0.5704568072344784), (7992, 0.5632869444054535), (8288, 0.563176184713327)]

# %%
from git import *

repos = open('data/msr_repo_list.txt').readlines()

# repo = 'cocos2d/cocos2d-x'

for repo in repos:

    pulls = get_pull_list(repo, False)

    num, tot = 0, 0
    for pull in pulls:
        tot += 1
        if len(get_pr_numbers(str(pull['title']) + str(pull['body']))) > 0:
            num += 1
    print(repo.strip(), ':', 1.0 * num / tot)

# %%
from main import *

# init_model_with_repo('Ultimaker/Ultimaker2Marlin')
init_model_with_repo('MarlinFirmware/Marlin')
get_sim_vector(get_pull('Ultimaker/Ultimaker2Marlin', '50'), get_pull('MarlinFirmware/Marlin', '1402'))

# %%
from main import *

# init_model_with_repo('ceph/ceph')

p1 = get_pull('hashicorp/terraform', '6827')
t = get_another_pull(p1)
print(type(t[0]))
print(get_another_pull(p1))

print(type(p1["number"]))
'''
p2 = get_pull('ceph/ceph', '10427')
print(get_BoW(p1["title"]))
print(get_BoW(p2["title"]))

print(get_sim('ceph/ceph', '10438', '10427'))

print(check_pattern(p1, p2))
'''

# %%
from main import *

# init_model_with_repo('Ultimaker/Ultimaker2Marlin')
init_model_with_repo('MarlinFirmware/Marlin')
get_sim_vector(get_pull('Ultimaker/Ultimaker2Marlin', '50'), get_pull('MarlinFirmware/Marlin', '1402'))

# %%
from main import *

# init_model_with_repo('Ultimaker/Ultimaker2Marlin')
init_model_with_repo('MarlinFirmware/Marlin')
get_pr_sim_vector(get_pull('Ultimaker/Ultimaker2Marlin', '50'), get_pull('MarlinFirmware/Marlin', '1402'))

# %%
import main
# main.init_model_with_repo('facebook/react')
# main.get_sim('facebook/react', '12767', '11770')

main.init_model_with_repo('facebook/react')
main.get_sim('facebook/react', '466', '433')

# %%
import main
main.init_model_with_repo('facebook/react')
main.get_sim('facebook/react', '12767', '11770')

# %%
import main
import git

# %time main.init_model_with_pulls(git.get_pull_list('MarlinFirmware/Marlin'))

'''
import main
main.init_model_with_repo('SignalR/SignalR')
main.get_sim('SignalR/SignalR', '3094', '3862')
'''

# %%
import re
def camel_case_split(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return [m.group(0) for m in matches]

print(camel_case_split('AasAdsaB'))
print(camel_case_split('dasAdsaBcdas'))
print(camel_case_split('ARM64'))

print(camel_case_split('321jca+dsad321_dsaAz'))

# %%
import main
c = main.classify() # all

"""
with open('tmp/1.txt') as f:
    for l in f.readlines():
        if len(l)<=3:
            continue
        p, n1, n2 = l.split()
        
        t = main.get_sim(p, n1, n2)
        
        print(c.predict([t])[0], p, n1, n2, t)
"""

with open('')
X_test = localfile_tool.get_file('data/improve_false_data_msr_positive_pairs_lsi_X.json')
y_test = localfile_tool.get_file('data/improve_false_data_msr_positive_pairs_lsi_y.json')

acc = c.score(X_test, y_test)
print('Mean Accuracy:', acc)

# c.predict()

# %%
import main
main.get_sim('mozilla-b2g/gaia', '2420', '2459')

# %%
import main
p = main.get_pull('mozilla-b2g/gaia', '2420')
f = fetch_pr_info(p)
print([x["name"] for x in f])

# %%
from main import *
from git import *
from comparer import *

repo = 'spring-projects/spring-framework'
init_model_with_pulls([], repo.replace('/','_') + '_all')
# init_model_with_repo(repo)

x = 'Changed min accepted day of month to 1'
y = 'Support for the last day in month cron expression'

'''
x = 'Tokenizer - removing unnecessary boxing'
y = 'Tokenizer - removes unnecessary boxing of char'
'''

# %timeit text_sim(x,y)
# text_sim(x,y)
'''
print(model.get_tfidf(get_BoW(x)))
print(model.get_tfidf(get_BoW(y)))
c = set(get_BoW(x)) & set(get_BoW(y))
print(model.get_idf_sum(c))
'''

# %%
from util import localfile
ps = localfile.get_file('data/msr_positive_pairs_feature_vector_all_clues_with_text_lsi_code_bow_X.json')
for p in ps:
    if p[0] >= 0.9:
        print(p[0], p[2])

# %%
from git import *
from comp import *

def func(file):

    num = 0
    tot = 0
    with open(file) as f:
        for f0 in f.readlines():
            r, n1, n2 = f0.split()
            p1 = get_pull(r, n1)
            p2 = get_pull(r, n2)
            s1 = get_tokens(p1['title'])
            s2 = get_tokens(p2['title'])
            if (set(s1) & set(s2)):
                t = len(s1) + len(s1)
                num += 1
                tot += t

    print (1.0 * tot / num)
    
func('data/clf/small_part_negative.txt')
func('data/clf/msr_positive_pairs.txt')

                                    
'''                      
with open('data/clf/manual_label_false.txt') as f:
    for t in f.readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        t = set(get_tokens(p1['title'])) & set(get_tokens(p2['title']))
        if t:
            print(t)
'''

# %%
from git import *
from comp import *

r = 'laravel/framework'

ps = get_repo_info(r, 'pull')
tot = 0
cnt = 0
for p in ps:
    cnt += 1
    print(cnt)

    file_list = fetch_pr_info(p)
    for file in file_list:
        tot += len(file["add_code"]) + len(file["del_code"])

print('tot=', tot)

# %%
from numpy import array
from numpy import median
from clf import *


def q(a):
    print('\t'.join(['{0:0.4f}'.format(1.0 * sum(a[:,i]) / len(a)) for i in range(len(a[0]))]))
    
    # print('\t'.join(['{0:0.4f}'.format(median(a[:,i])) for i in range(len(a[0]))]))
    
f = []
no = []
yes = []
for s in dataset:
    new_X, new_y = get_feature_vector(s[0], s[1], model_data_renew_flag, model_data_save_path_suffix)
    
    if ('true' in s[0]) or ('msr' in s[0]):
        yes += new_X
    else:
        no += new_X

no = array(no)
yes = array(yes)

# q(no)
# q(yes)


# sum(L) / float(len(L))

# %%
from clf import *
from comp import *

last = None
q = []

cnt = {}

with open('/home/luyao/PR_get/INTRUDE/data/clf/manual_label_true.txt') as f:
    for pair in f.readlines():
        r, n1, n2 = pair.split()
        
        if r != last:
            last = r
            # init_model_with_repo(r)
            print('cnt', r)
            cnt = {}
            ps = get_repo_info(r, 'pull')
            for p in ps:
                for x in get_tokens(p['title']):
                    if x not in cnt:
                        cnt[x] = 0
                    cnt[x] += 1
        
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        def add(p):
            x = [cnt.get(word, 0) for word in get_tokens(p['title'])]
            q.append(sum(x) / len(x))
            
        add(p1)
        add(p2)

print(sum(q) / len(q))

# %%
from clf import *
from comp import *

init_model_with_repo('bitcoin/bitcoin')
p1 = get_pull('peercoin/peercoin', '219')
p2 = get_pull('bitcoin/bitcoin', '5509')

print(get_pr_sim_vector(p1, p2))

# %%
files = [
'/home/luyao/PR_get/INTRUDE/data/clf/manual_label_false.txt',
#'/home/luyao/PR_get/INTRUDE/data/clf/manual_label_true.txt',
'/home/luyao/PR_get/INTRUDE/data/clf/openpr_label_false.txt',
#'/home/luyao/PR_get/INTRUDE/data/clf/openpr_label_true.txt'
]

for file in files:
    for t in open(file).readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        def add(p1):
            file_list = fetch_pr_info(p1)
            return sum([x["LOC"]['add'] for x in file_list])
        def dele(p1):
            file_list = fetch_pr_info(p1)
            return sum([x["LOC"]['del'] for x in file_list])
        
        
        print(t.strip(), 'line=', '+%d,-%d' % (add(p1), dele(p1)) , '\t', '+%d,-%d' % (add(p2), dele(p2)))
        print(p1['title'])
        print(p2['title'])
        
        print('------')
    
        '''
        file_list = fetch_pr_info(p1)
        if len(file_list) <= 10:
            #print(p1['title'], ':', [x['name'] for x in file_list])
            t = sum([x["LOC"]['add'] for x in file_list])
            if t <= 10:
                print(r, n1, n2, p1['title'], ':', t)
        '''
# Out:
# CleverRaven/Cataclysm-DDA 13493 11313 line= +1,-1 	 +9,-0
# Expands Wilderness scenario profession choices.
# Add Arrested Scenario
# ------
# CleverRaven/Cataclysm-DDA 10005 8445 line= +9,-8 	 +1,-4
# Miscellaneous bug fixes
# Fixed bug #8440
# ------
# laravel/framework 1592 959 line= +13,-0 	 +3,-2
# Adding support for HTML5 date input to the HTML FormBuilder
# Added possibility of a value to password input in FormBuilder
# ------
# facebook/react 8464 2511 line= +1,-1 	 +39,-0
# Ensure ReactTransitionGroup.state.children is always object
# Add componentWillEnterOnMount to ReactTransitionGroup children
# ------
# CleverRaven/Cataclysm-DDA 23179 17029 line= +223,-300 	 +106,-140
# Seeds migration to a dedicated file (pt. 1)
# [WIP]Migrate seeds part 2
# ------
# CleverRaven/Cataclysm-DDA 17134 6793 line= +91,-70 	 +17,-0
# World options
# Add world option for vanishing wildlife
# ------
# CleverRaven/Cataclysm-DDA 23991 19357 line= +1,-1 	 +1,-1
# wild_herbs + 1 herb in description
# Remove pork from description of mannwurst
# ------
# laravel/framework 2600 1663 line= +32,-36 	 +28,-19
# Docblocks fixes for Auth
# Fixes - Auth
# ------
# laravel/framework 2883 2380 line= +4,-1 	 +7,-1
# Update to Validator->validateAccepted(), accounts for (int) 0 values ensuring that they do not validate
# [Fix Bug] Error when trying validate (getSize) a value of specific array...
# ------
# laravel/framework 3007 2926 line= +10,-4 	 +2,-2
# QueryException improvements
# Fix typo in QueryException comment
# ------
# laravel/framework 4447 2986 line= +1,-1 	 +2,-0
# Downgrade symfony/http-foundation to temporarily fix session persistence issues
# Symfony Fixes
# ------
# laravel/framework 4758 1146 line= +42,-2 	 +47,-1
# [Bug] Unable to limit and order unions
# Add union method to Query Builder
# ------
# laravel/framework 4907 2176 line= +38,-0 	 +823,-788
# [4.2] Add Only And Except Methods To The Collection
# Add reduce function to Collection
# ------
# laravel/framework 5077 4462 line= +30,-0 	 +35,-0
# [4.2] Validator : add hexadecimal validator
# Added domain validation
# ------
# laravel/framework 5815 4456 line= +1,-1 	 +0,-0
# [4.2] Validator : fix validator docblock
# added domain validation
# ------
# laravel/framework 8632 1886 line= +2,-1 	 +2,-2
# #8629 - Add symofny/var-dumper dependency to composer
# Patchwork should be a required dependency.
# ------
# laravel/framework 9203 5077 line= +30,-1 	 +30,-0
# [5.1] validateMimes does not do what it says
# [4.2] Validator : add hexadecimal validator
# ------
# laravel/framework 9323 8211 line= +4,-2 	 +13,-5
# Cache input value
# Input::has should return true when a null value is given
# ------
# laravel/framework 10256 1532 line= +1,-1 	 +513,-546
# [5.1] PHPDoc should @return bool instead of void
# Fix phpDoc typos
# ------
# laravel/framework 15003 13223 line= +2,-2 	 +1,-5
# [5.3] firstOrCreate and New should use forceFill
# [5.2] Use firstOrNew inside firstOrCreate
# ------
# laravel/framework 16581 15660 line= +0,-4 	 +8,-3
# [5.3] Update Validator.php
# [5.3] Update Validator.php
# ------
# laravel/framework 16879 4628 line= +16,-0 	 +15,-0
# [5.3] Add nullable morph columns
# [Proposal] Add nullableMorphs
# ------
# laravel/framework 17908 12810 line= +1,-1 	 +11,-1
# #17881 - AuthenticatesUsers logout redirects to /
# [5.2] Add "redirectAfterLogout" method to "AuthenticatesUsers" trait
# ------
# laravel/framework 18540 7883 line= +7,-2 	 +53,-9
# [5.4] Add support for multiple --path to migrate:reset
# Adds "--path" to the migrate:reset command
# ------
# laravel/framework 19022 8801 line= +5,-0 	 +6,-0
# [5.5] clone query without order by for aggregates
# [5.0] Logic error using Aggregate + Order By
# ------
# laravel/framework 20043 19240 line= +45,-0 	 +75,-0
# [5.4] Add @dump() blade directive
# [5.5] Add Blade @class directive
# ------
# laravel/framework 21471 14090 line= +41,-0 	 +70,-0
# [5.5] Add loadMissing to EloquentCollection
# [5.2] Add loadOnly() method to only load specified relations
# ------
# laravel/framework 21902 18997 line= +10,-1 	 +438,-329
# [5.5] Fix eager loading HasManyThrough relations with custom intermediate and local key
# [5.4] add a "second local key" to HasManyThrough
# ------
# Apple/swift 251 206 line= +1,-1 	 +1,-1
# Link to swift.org in README
# Changing the hyperlink word in README.md from 'the website' to 'Swift.org'
# ------
# Apple/swift 395 113 line= +2,-0 	 +1,-0
# Add some cool badges to README
# Added Swift logo with properly width to Readme (SVG from Swift.org)
# ------
# Apple/swift 1162 539 line= +6,-0 	 +1,-1
# [README] Build status from ci.swift.org
# Add link to swift.org in README.md title
# ------
# Apple/swift 4216 3058 line= +24,-4 	 +66,-46
# [utils] Add support to checkout swift-3.0-branch for llvm, clang, com…
# [update-checkout] Use subparsers to split clone/update paths.
# ------
# Apple/swift 7737 3825 line= +2,-1 	 +10,-8
# Fix update-checkout flake8 errors
# [update-checkout] Echo some git commands for update-checkout.
# ------
# facebook/react 3969 3807 line= +20,-14 	 +434,-448
# Fix PropTypes.{oneOf, oneOfType} validation
# Adding proper validation for PropType oneOf and OneOfType.
# ------
# facebook/react 11868 4426 line= +2,-8 	 +1,-1
# Fix typos
# Fixed typo
# ------
# facebook/react 12488 10255 line= +53,-1 	 +7,-0
# Add React 16.3.0 changelog
# Changelog for 15.6.1
# ------
# facebook/react 12621 10255 line= +18,-0 	 +7,-0
# Add 16.3.2 changelog
# Changelog for 15.6.1
# ------
# elastic/elasticsearch 10782 9563 line= +22,-70 	 +48,-62
# Update the experimental annotations in the docs
# Docs: Use the new experimental annotation.
# ------
# elastic/elasticsearch 19320 10305 line= +2,-2 	 +2,-2
# slight clarification
# Update for clarification
# ------
# elastic/elasticsearch 23184 6253 line= +596,-0 	 +2,-2
# Add new DateRangeQueryBuilder
# Documentation Query string date range
# ------
# elastic/elasticsearch 2324 1775 line= +5,-5 	 +14,-0
# Fix for Issue #2322
# Fix for issue 1774
# ------
# elastic/elasticsearch 8750 6864 line= +71,-2 	 +75,-105
# Add explicit error message when script_score script returns NaN
# Remove setNextScore in SearchScript.
# ------
# elastic/elasticsearch 15733 9027 line= +101,-7 	 +13,-35
# Faster terms filter when cached
# Terms filter lookup caching should cache values, not filters.
# ------
# rust-lang/rust 6054 4610 line= +387,-178 	 +2614,-2208
# Rustpkg
# Rustpkg
# ------
# Apple/swift 431 402 line= +16,-8 	 +8,-16
# Revert "Fix TODO by removing unneeded ShouldSerializeAll parameters."
# Fix TODO by removing unneeded ShouldSerializeAll parameters.
# ------
# Apple/swift 1985 1949 line= +42,-81 	 +62,-43
# Revert "Runtime: Fix problems with nil-to-nil casts"
# Runtime: Fix problems with nil-to-nil casts [master]
# ------
# Apple/swift 5903 2862 line= +29,-1 	 +35,-10
# Enable SourceKit building by default on Linux
# [SourceKit] Link with libdispatch on Linux
# ------
# Apple/swift 3026 2793 line= +940,-1 	 +8,-7
# [SourceKit] In-Proc implementation of sourcekitd API functions
# [SR-1639] Move sourcekitdInProc to std::mutex
# ------
# CocoaPods/Specs 40 20 line= +27,-0 	 +12,-0
# Please add this pod spec
# Added a RegexKitLite spec
# ------
# laravel/framework 22292 21482 line= +3,-0 	 +12,-0
# [5.6] Add air, sugar and water to $uncountable
# [5.6] Add more uncountable nouns
# ------
# laravel/framework 24173 19489 line= +3,-3 	 +55,-2
# [5.6] Fix signature for orWhere() not matching where()
# Builder orWhereRaw same operation as whereRaw and BeforeQueryExecuted event
# ------
# laravel/framework 24400 24399 line= +58,-2 	 +2,-0
# [5.6] Fix: soft-delete does not sync original
# Fix soft-delete does not sync original.
# ------
# laravel/framework 24536 22339 line= +15,-0 	 +46,-0
# [5.6] add assertOk() response assertion
# [5.5] Add assertJsonModel and assertJsonModels to TestResponse
# ------
# rust-lang/rust 11301 8220 line= +128,-47 	 +46,-7
# Fix ARM unwinding.
# Add support for vanilla linux on arm.
# ------
# rust-lang/rust 44784 44761 line= +309,-58 	 +97,-17
# Rollup of 14 pull requests
# Rollup of 7 pull requests
# ------
# rust-lang/rust 1108 295 line= +56,-53 	 +1,-0
# Doc: Sort keywords alphabetically
# Add 'self' keyword.
# ------
# rust-lang/rust 45003 44907 line= +482,-383 	 +735,-400
# Beta
# Beta 20170928
# ------
# rust-lang/rust 51092 31032 line= +24,-0 	 +153,-0
# [master] Release notes for 1.26.1
# Release notes for 1.6
# ------
# Apple/swift 12206 6911 line= +2,-2 	 +2,-2
# Minor grammar fixes to README
# Update README.md
# ------
# elastic/elasticsearch 25641 23362 line= +64,-60 	 +108,-95
# Upgrade to lucene-7.0.0-snapshot-00142c9.
# Upgrade to lucene-6.5.0-snapshot-d00c5ca
# ------
# elastic/elasticsearch 27619 23362 line= +31,-29 	 +108,-95
# Upgrade to lucene-7.2.0-snapshot-8c94404.
# Upgrade to lucene-6.5.0-snapshot-d00c5ca
# ------
# elastic/elasticsearch 31360 23362 line= +27,-25 	 +108,-95
# Upgrade to Lucene-7.4.0-snapshot-518d303506
# Upgrade to lucene-6.5.0-snapshot-d00c5ca
# ------
# elastic/elasticsearch 12544 12538 line= +248,-15 	 +24,-8
# Default position_offset_gap to 100
# Updating default position_offset_gap to 10.
# ------
# elastic/elasticsearch 6287 6058 line= +1,-3 	 +6,-4
# Update repositories.asciidoc
# Update repositories.asciidoc
# ------
# Apple/swift 29 20 line= +11,-11 	 +22,-15
# Use https instead of git@ for cloning instructions
# [README] syntax highlighting!
# ------
# rust-lang/rust 27171 12819 line= +229,-0 	 +34,-0
# Write better docs for std::io
# doc: discuss try! in std::io
# ------
# rust-lang/rust 51310 22327 line= +105,-17 	 +509,-194
# Rollup of 6 pull requests
# Rollup of 31 pull requests
# ------
# facebook/react 10255 6673 line= +7,-0 	 +24,-0
# Changelog for 15.6.1
# Added React v15.0.2 changelog
# ------
# laravel/framework 20410 19057 line= +59,-0 	 +29,-0
# [5.5] Add mergeWith method to Collection
# [5.4] Add collection deep merge
# ------
# elastic/elasticsearch 23750 19496 line= +105,-69 	 +34,-31
# Upgrade to Lucene 6.5.0
# Upgrade lucene to 5.5.2
# ------
# elastic/elasticsearch 15330 14505 line= +255684,-211280 	 +336024,-257449
# Make FsProbe configurable for plugins
# Update upgrade.asciidoc
# ------
# elastic/elasticsearch 8962 7267 line= +5,-5 	 +1,-1
# typo on "frequent"
# Docs: Fixed a typo
# ------
# elastic/elasticsearch 10029 4489 line= +7,-6 	 +2,-3
# Fix some docs n typos
# [Docs] Fix Typo
# ------
# elastic/elasticsearch 13897 8982 line= +4,-6 	 +1,-1
# Update `cat allocation` doc
# [docs] pedantry
# ------
# apache/spark 21243 19616 line= +112,-103 	 +147,-62
# [SPARK-24182][yarn] Improve error message when client AM fails.
# [SPARK-22404][YARN] Provide an option to use unmanaged AM in yarn-client mode
# ------
# apache/spark 20570 6154 line= +33,-6 	 +94,-12
# [spark-23382][WEB-UI]Spark Streaming ui about the contents of the for need to have hidden and show features, when the table records very much.
# [SPARK-7645][Streaming][WebUI]Show milliseconds in the UI if the batch interval < 1 second
# ------
# apache/spark 20368 13244 line= +18,-2 	 +114,-26
# [SPARK-23195] [SQL] Keep the Hint of Cached Data
# [SPARK-15415][SQL] Fix BroadcastHint when autoBroadcastJoinThreshold is 0 or -1
# ------
# apache/spark 20365 13244 line= +21,-4 	 +114,-26
# [SPARK-23192] [SQL] Keep the Hint after Using Cached Data
# [SPARK-15415][SQL] Fix BroadcastHint when autoBroadcastJoinThreshold is 0 or -1
# ------
# apache/spark 20307 16768 line= +16,-4 	 +19,-3
# [SPARK-23141][SQL][PYSPARK] Support data type string as a returnType for registerJavaFunction.
# Support data type string as a returnType argument of UDF
# ------
# apache/spark 19957 19721 line= +16,-14 	 +14,-12
# [DO-NOT-MERGE] Check if 19721 breaks a CRAN
# [SPARK-22496][SQL]thrift server adds operation logs
# ------
# apache/spark 19774 16422 line= +93,-27 	 +332,-15
# [SPARK-22475][SQL] show histogram in DESC COLUMN command
# [SPARK-17642] [SQL] support DESC EXTENDED/FORMATTED table column commands
# ------
# apache/spark 19024 17324 line= +256,-7 	 +244,-1
# [SPARK-21469][ML][EXAMPLES] Adding Examples for FeatureHasher
# [SPARK-19969] [ML] Imputer doc and example
# ------
# apache/spark 18849 14750 line= +171,-28 	 +245,-97
# [SPARK-21617][SQL] Store correct table metadata when altering schema in Hive metastore.
# [SPARK-17183][SPARK-17983][SPARK-18101][SQL] put hive serde table schema to table properties like data source table
# ------
# apache/spark 19533 19162 line= +0,-0 	 +0,-0
# Merge pull request #1 from apache/master
# Merge pull request #1 from apache/master
# ------
# Apple/swift 51 20 line= +16,-6 	 +22,-15
# Update some Readme strucutre and styles
# [README] syntax highlighting!
# ------
# CocoaPods/Specs 5196 5020 line= +42,-0 	 +2,-2
# Bump version to 2.1.0.
# Bump version to 3.6.3
# ------
# Apple/swift 206 111 line= +1,-1 	 +1,-0
# Changing the hyperlink word in README.md from 'the website' to 'Swift.org'
# Added Swift Logo to the Readme
# ------
# facebook/react 10115 6928 line= +1,-0 	 +13,-0
# Treat columns property as a unitless number
# Remove 'unitless number' warning for 'content' style properties
# ------
# kubernetes/kubernetes 41296 41271 line= +148,-0 	 +286,-162
# implement configmap upgrade test
# Implements an upgrade test for Job
# ------
# kubernetes/kubernetes 56283 31084 line= +55245,-1108 	 +182950,-298079
# Release 1.9
# Release 1.1
# ------
# CocoaPods/Specs 9016 1328 line= +24,-0 	 +2,-2
# Updated to version 0.3.7
# Updating version
# ------
# CocoaPods/Specs 10001 6155 line= +17,-0 	 +26,-0
# YGLibrary
# Apache Thrift - 0.8.0 and 0.9.0 Libraries
# ------
# facebook/react 1664 1026 line= +29,-12 	 +101,-0
# Add helpful message about pooled classes
# Ensure a pooled class releases back into the pool an instance of that class
# ------
# laravel/framework 17048 7603 line= +153,-306 	 +147,-140
# [5.5] Prepped the master branch for Laravel 5.5
# Master
# ------
# laravel/framework 24149 3791 line= +13,-4 	 +20,-3
# Container: allow make() with unnamed parameters
# Classes bound by name into container were not receiving parameters
# ------
# rails/rails 8288 7075 line= +14,-0 	 +50,-0
# add ActiveModel::Errors#to_s
# Added method unique_messages to ActiveModel::Errors
# ------
# rails/rails 9602 8313 line= +24,-3 	 +24,-2
# Fix #8856 Ensure has_one association=(associate) triggers save.
# Save has_one associations only if record has changes
# ------
# rails/rails 10231 8525 line= +93,-3 	 +170,-5
# Support for PostgreSQL citext data type.
# AR supporting new int4range and int8range data type on PostgreSQL >= 9.2
# ------
# rails/rails 15740 3762 line= +10,-1 	 +4,-1
# Add more exceptions on pluralization for -fe/-ve endings
# 'criterion'.pluralize => 'criteria'
# ------
# rails/rails 18384 6594 line= +9,-1 	 +5,-0
# Prevent the retrieve_cache_key to infinite loop
# Backport cache key patch
# ------
# rails/rails 20006 2638 line= +1,-8 	 +2,-2
# refactor ActiveSupport::TestCase.test_order method with memoization
# Remove trailing whitespace from ActiveSupport::TestCase
# ------
# elastic/elasticsearch 5677 5589 line= +103,-17 	 +50,-12
# Take stream position into account when calculating remaining length
# Restore streamInput() performance over PagedBytesReference.
# ------
# elastic/elasticsearch 5647 4044 line= +76,-10 	 +3022,-134
# Geo context suggester: Require precision in mapping
# ContextSuggester
# ------
# Apple/swift 7165 3825 line= +18,-10 	 +10,-8
# utils/update-checkout: Do any ``git checkout`` before the ``git fetch``.
# [update-checkout] Echo some git commands for update-checkout.
# ------
# Apple/swift 9649 6876 line= +10,-0 	 +5,-1
# Add references to CHANGELOG.md
# Update CHANGELOG.md
# ------
# docker/docker 31877 23586 line= +1,-6 	 +20,-17
# Add bash completion for `update --cpus`
# Additional bash completions
# ------
# docker/docker 8235 3547 line= +84,-8 	 +67,-4
# Add checks for app/json - issue #2515
# if JSON object is null, return []
# ------
# cocos2d/cocos2d-x 2850 2690 line= +9,-1 	 +4,-1
# Making CCScrollView zoom behaving more like a UIScrollView when a user tries
# CCScrollView: 2-finger-pinch/zoom buggy, so disabled it
# ------
# saltstack/salt 33139 25748 line= +35,-7 	 +1,-1
# Back-port #31769 to 2015.8
# Back-port #25744 to 2015.5
# ------
# saltstack/salt 27682 25748 line= +10,-9 	 +1,-1
# Back-port #27566 to 2015.5
# Back-port #25744 to 2015.5
# ------
# saltstack/salt 23427 23396 line= +122,-48 	 +85,-23
# Merge forward from 2014.7->2015.5
# [2015.2] Merge forward from 2014.7 to 2015.2
# ------
# saltstack/salt 29650 25091 line= +11,-2 	 +2,-2
# Adding ability to disable npm install silent flag
# Removed --silent flag from npm install calls.
# ------
# cocos2d/cocos2d-x 18753 16987 line= +27,-5 	 +42,-7
# Support for non-breaking characters in label
# Do not wrap label on non-wrappable spaces (fixes #16939)
# ------
# cocos2d/cocos2d-x 12175 7125 line= +3,-0 	 +3,-1
# issue #10323: Fix the compile error when COCOS2D_DEBUG>=2.
# CCLOGINFO compilation fix
# ------
# cocos2d/cocos2d-x 11285 9494 line= +398,-129 	 +6,-0
# Update UIRichText
# RichText can handle ImageRenderer created with frame name
# ------
# mrdoob/three.js 13428 8421 line= +12,-0 	 +73,-57
# DirectGeometry: clone bounding volumes in fromGeometry method
# DirectGeometry: Support for Line Geometries in .fromGeometry
# ------
# mrdoob/three.js 13082 14072 line= +1,-1 	 +2,-13
# Update Fileloader's judgment to http code.
# FileLoader: Remove redundant code
# ------
# mrdoob/three.js 14471 14015 line= +39,-18 	 +30,-9
# GLTFExporter: Serialize userData.gltfExtensions
# GLTFExporter: Serialize material.userData
# ------
# spring-projects/spring-framework 810 1212 line= +19,-0 	 +93,-22
# Add nullToEmpty convenience method to StringUtils
# add some utility methods for StringUtils
# ------
# spring-projects/spring-framework 1589 346 line= +69,-0 	 +22,-0
# SPR-16171 MediaType, add application/schema+json
# Restore method signatures on MediaType
# ------
# spring-projects/spring-framework 1823 1402 line= +1,-1 	 +20,-1
# Changed min accepted day of month to 1
# Support for the last day in month cron expression
# ------
# spring-projects/spring-framework 1431 1068 line= +150,-6 	 +38,-1
# add value predicate support in BeanUtils.copyProperties()
# let BeanUtils.copyProperties support to copy generic property
# ------
# spring-projects/spring-framework 277 1140 line= +859,-428 	 +81,-7
# Add support for @Parameters in SpringJUnit4ClassRunner
# SpringJUnit4ClassRunner should be thread safe
# ------
# hashicorp/terraform 17438 13112 line= +1,-1 	 +8,-0
# helper/acctest: Fix RandIntRange function
# helper/acctest: Add RandIntRange helper function
# ------
# hashicorp/terraform 17259 16675 line= +1,-1 	 +2,-2
# Fix typo in chunklist() documentation
# Fix chunklist examples typo
# ------
# hashicorp/terraform 6216 6827 line= +745,-11 	 +330,-0
# [WIP] Add a new Docker communicator
# [WIP] communicator: docker communicator
# ------
# hashicorp/terraform 17450 15989 line= +125,-139 	 +82,-0
# Fix default values in salt masterless provisioner
# Add grains_file parameter to salt-masterless provisioner
# ------
# hashicorp/terraform 18377 16549 line= +1,-1 	 +5,-0
# Update interpolation.html.md
# Update interpolation.html.md
# ------
# hashicorp/terraform 13408 8993 line= +75,-0 	 +62,-4
# vcd provider: adds support for setting OVF guest properties in vcd_vapp resource
# provider/vcd: Support to add ovf parameter in vapp
# ------
# hashicorp/terraform 13019 1594 line= +49,-3 	 +175,-1
# Added supported for ConflictsWith for fields within lists/sets
# Add schema.ConflictsWith[]
# ------
# hashicorp/terraform 14102 14894 line= +35,-8 	 +7,-2
# fixes #13064: website: `terraform` block docs now link to "Backends Configuration"
# [docs] update terraform configuration page to include backends
# ------
# hashicorp/terraform 17499 3505 line= +101,-12 	 +14,-3
# helper/schema: Decode map values per Elem for ValidateFunc
# helper/schema: ValidateFunc support for maps
# ------
# hashicorp/terraform 9924 14584 line= +85,-0 	 +34,-7
# Add base_archive option to archive_file resource
# Archive provider docs
# ------
# hashicorp/terraform 17839 16785 line= +92,-0 	 +1,-1
# Docs: Add diff customization to the custom provider guide
# Update writing-custom-terraform-providers.html.md
# ------
# cocos2d/cocos2d-x 18526 13785 line= +1264,-197 	 +148,-41
# Add new types support to CCValue
# Add support for Unsigned with CCValue
# ------
# cocos2d/cocos2d-x 17527 17483 line= +126,-3 	 +100,-0
# Updates PR #17476 (Remove _claimedTouches Flags for listeners)
# Cpp test code for Pull request (Issue 17476)
# ------
# cocos2d/cocos2d-x 14860 11414 line= +1,-1 	 +1,-1
# Update CCLabel.cpp
# Update CCLabel.cpp
# ------
# cocos2d/cocos2d-x 14446 11864 line= +13,-2 	 +8,-6
# Fixed AssetsManager bug.
# Update AssetsManager.cpp
# ------
# cocos2d/cocos2d-x 18639 15596 line= +1,-1 	 +1,-1
# fix 3d animation
# fix animate 3d bug
# ------
# cocos2d/cocos2d-x 15819 14108 line= +8,-8 	 +10,-9
# CCFontFreeType : Changed the type of parameter 'outline' from int to float.
# Changed label font size type to float
# ------
# cocos2d/cocos2d-x 15120 7028 line= +323,-0 	 +4,-0
# Add 'trap' command to the CCConsole
# [ccconsole]Add version command.
# ------
# cocos2d/cocos2d-x 14734 18400 line= +13,-1 	 +17,-0
# Support localStorage and third party cookie on Cocos2dxWebView.
# Update Cocos2dxWebView.java
# ------
# django/django 9391 8776 line= +11,-1 	 +5,-5
# Fixed #28404 -- showing empty value for empty strings in Django admin
# [WIP] Fixes #28404 -- Show empty_value for empty strings
# ------
# django/django 8803 220 line= +77,-0 	 +1,-1
# Fixed #27994 -- Documented contrib.staticfiles.storage.ManifestFilesM…
# Fix typo in staticfiles app documentation
# ------
# django/django 9581 5322 line= +97,-33 	 +23,-10
# ModelBackend object permissions fallback to model permissions
# Made object permission behave like model permission in default ModelBackend
# ------
# emberjs/ember.js 16701 16487 line= +2,-0 	 +1,-0
# [Documentation] Available queryParam types
# [DOC release] Ensure queryParams is documented in Controller.
# ------
# emberjs/ember.js 15050 14794 line= +45,-0 	 +55,-3
# Failing Test: Sticky Query Parameters with Loading Template in Engine
# Fix query param stickiness between models in ember-engines
# ------
# facebook/react 13210 13225 line= +23,-48 	 +95,-71
# Synthetic event simplify
# Remove the use of proxies for synthetic events in DEV
# ------
# elastic/elasticsearch 31378 27808 line= +34,-42 	 +1,-1
# Update update-settings.asciidoc
# Update update-settings.asciidoc
# ------
# elastic/elasticsearch 31295 22370 line= +1,-1 	 +1,-1
# Update getting-started.asciidoc
# Update getting-started.asciidoc
# ------
# elastic/elasticsearch 29518 31295 line= +2,-1 	 +1,-1
# Update getting-started.asciidoc
# Update getting-started.asciidoc
# ------
# ArduPilot/ardupilot 8732 5657 line= +272,-2 	 +200,-6
# AP_Proximity: TeraRanger Tower Evo support
# Support for TeraRangerTower
# ------
# ArduPilot/ardupilot 7451 6686 line= +89,-1 	 +237,-290
# AP_Arming: Add battery temperature check to the arming check.
# Arming check function
# ------
# ArduPilot/ardupilot 7943 5662 line= +56,-4 	 +163,-18
# AP_BattMonitor: Monitor the Maxell battery with Pixhawk2.
# AP_BattMonitor: Added Maxell Battery support
# ------
# ArduPilot/ardupilot 8363 5541 line= +97,-23 	 +211,-0
# AP_Baro: rewritten BMP280 driver to fix glitches
# AP_Baro: Add Bosch BMP280 barometer driver
# ------
# ArduPilot/ardupilot 7721 7783 line= +316,-71 	 +509,-187
# WIP: ChibiOS: Plane: print thread statistics
# ChibiOS support - part 5
# ------
# ArduPilot/ardupilot 8904 7681 line= +711,-455 	 +740,-8
# AP_HAL_ChibiOS: use MML for tonealarm
# ChibiOS tonealarm
# ------
# ArduPilot/ardupilot 8919 8807 line= +14,-0 	 +127,-8
# Osd add temperature item
# AP_OSD: new osd items
# ------
# pydata/pandas 21930 21614 line= +9,-6 	 +28,-13
# DEPR: Series.compress
# DEPR: Series.ptp()
# ------
# pydata/pandas 20913 20864 line= +136,-4 	 +50,-7
# DOC: update the Series.str.ismethods docstring
# DOC: Improve the docstring of String.str.zfill()
# ------
# pydata/pandas 20465 20131 line= +59,-26 	 +46,-8
# DOC: update the pandas.DatetimeIndex docstring
# DOC: update pandas.DatetimeIndex.to_period docstring(Nairobi)
# ------
# pydata/pandas 20381 20379 line= +125,-10 	 +147,-7
# DOC: update pandas.core.resample.Resampler.nearest docstring
# DOC: update the pandas.core.resample.Resampler.fillna docstring
# ------
# pydata/pandas 20218 20275 line= +62,-2 	 +40,-1
# DOC: update the series.dt.weekofyear docstring
# DOC: update the pandas.Series.dt.is_year_start docstring
# ------
# pydata/pandas 20213 20182 line= +40,-0 	 +46,-1
# DOC: Updated docstring DatetimeIndex.ceil
# DOC: Update the DatetimeIndex.floor docstring
# ------
# pydata/pandas 20170 20121 line= +73,-7 	 +70,-13
# DOC: update the pandas.DataFrame.plot.area docstring
# DOC: updated the pandas.DataFrame.plot.hexbin docstring
# ------
# pydata/pandas 20153 20154 line= +29,-6 	 +54,-6
# DOC: Update the pandas.Series.str.find() (Delhi)
# DOC: Update the pandas.Series.str.count() docstring (Delhi)
# ------
# tensorflow/tensorflow 18848 18846 line= +19,-12 	 +3,-4
# Add int8 support to div operations
# Enable int8 support for FloorDiv
# ------
# tensorflow/tensorflow 15861 14578 line= +202,-90 	 +217,-0
# Fix LSTM Layer Normalization implementation to match original paper
# Implements LayerNormBasicGRUCell
# ------
# tensorflow/tensorflow 19604 19255 line= +114,-64 	 +148,-290
# Fix Android Build
# Android build fixes
# ------
# tensorflow/tensorflow 18567 20520 line= +9,-9 	 +5,-5
# Fix expand_dims of dim argument has been deprecated with axis
# Update calling of expand_dims with axis
# ------
# tensorflow/tensorflow 17954 20455 line= +6,-0 	 +1,-1
# Fix the feature shape of maxout output
# fix bug in maxout function
# ------

# %%
files = [
    '/home/luyao/PR_get/INTRUDE/data/clf/small_part_msr.txt',
    '/home/luyao/PR_get/INTRUDE/data/clf/rly_false_pairs.txt'
]

from datetime import datetime, timedelta

def get_time(t):
    return datetime.strptime(t, "%Y-%m-%dT%H:%M:%SZ")

from git import *

for file in files:
    q = []
    for t in open(file).readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        d = abs((get_time(p1['created_at']) - get_time(p2['created_at'])).days)
        q.append(d)

    print(sum(q) / len(q))
    print(sorted(q))

# %%
from git import *
# % timeit t = get_pull(, )

% timeit t = api.get('repos/%s/pulls/%s' % ('facebook/react', '12391'))

print(t)
# Out:
# 145 ms ± 10.7 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f271f64bdbe8> in <module>()
#       4 get_ipython().run_line_magic('timeit', "t = api.get('repos/%s/pulls/%s' % ('facebook/react', '12391'))")
#       5
# ----> 6 print(t)
#
# NameError: name 't' is not defined
