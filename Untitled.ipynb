# %%
import os
way = 'new'
file = 'detection/result_on_topk_%s_tmp.txt' % way

# file = 'detection/result_on_topk_pre_v3.txt'

cnt_num = 0
top_acc = [0 for i in range(30)]

last_run = {}
if os.path.exists(file):
    with open(file) as f:
        for t in f.readlines():
            ps = t.replace(',','').replace('[','').replace(']','').split()
            
            
            r, n1, n2 = ps[0], ps[1], ps[2]
            li = [int(x) for x in ps[3:]]
            
            '''
            if r != 'angular/angular.js':
            # if r != 'rails/rails':
            # if r != 'elastic/elasticsearch':
                continue
            '''
            
            cnt_num += 1
            for i in range(30):
                if int(n1) in li[:i+1]:
                    top_acc[i] += 1
            
            # print('now=', r, cnt_num, 'top1 acc =', 1.0 * top_acc[0] / cnt_num)
            
            '''
            if (r, n1, n2) == ('angular/angular.js', '5746', '9827'):
                break
            '''

print(cnt_num)
for i in range(30):
    t = 1.0 * top_acc[i] / cnt_num
    top_acc[i] = t
    print('top%d acc \t %.4f' % (i+1, t))

# %%
from git import *

r = 'elastic/elasticsearch'
t = open('ok.txt', 'w')
with open('evaluation/%s_select.txt' % r.replace('/', '_')) as f:
    for n in f.readlines():
        p = get_pull(r, n.strip())
        if not check_large(p):
            print(n.strip(), file=t)
t.close()

# %%
from git import *
from comp import *

def cp(p1, p2):
    if set(p2['title'].split()) & set(p1['title'].split()):
        return True
    
    if set([x['name'] for x in fetch_pr_info(p1)]) & set([x['name'] for x in fetch_pr_info(p2)]):
        return True
    
    if check_pattern(p1, p2) == 1:
        return True

    return False

r = 'laravel/framework'

pulls = get_repo_info(r, 'pull')

p = get_pull(r, '22057')

num, tot = 0, 0
for p2 in pulls:
    tot += 1
    if cp(p, p2):
        num += 1
    if tot % 100 == 0:
        print(1.0 * num / tot)

print(1.0 * num / len(pulls))

# %%
from git import *
from comp import *

def cp(p1, p2):
    if set(p2['title'].split()) & set(p1['title'].split()):
        return True
    
    if set([x['name'] for x in fetch_pr_info(p1)]) & set([x['name'] for x in fetch_pr_info(p2)]):
        return True
    
    if check_pattern(p1, p2) == 1:
        return True

    return False
    
num, tot = 0, 0
file = 'data/clf/msr_positive_pairs.txt'
with open(file) as f:
    for t in f.readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        tot += 1
        if cp(p1, p2):
            num += 1
        else:
            print(r, n1, n2)
        
        if tot % 100 == 0:
            print(1.0 * num / tot)

print(1.0 * num / tot)

# %%
from git import *

r = 'laravel/framework'

pulls = get_repo_info(r, 'pull')

def f():
    cnt = 0
    for p in pulls:
        t = fetch_pr_info(p)
        cnt += 1
        if cnt == 100:
            break

# %timeit f()

# %%
from git import *
from comp import *
from clf import *

c=classify()
lastr = None

file = 'detection/result_on_topk_new.txt'
out = 'detection/result_on_topk_new_thres.txt'

with open(file) as f:
    for t in f.readlines():
        ps = t.replace(',','').replace('[','').replace(']','').split()            
        r, n1, n2 = ps[0], ps[1], ps[2]
        li = [int(x) for x in ps[3:]]

        if lastr != r:
            init_model_with_repo(r)
            lastr = r

        t1 = c.predict_proba([get_sim(r, n2, n1)])[0][1]
        t2 = c.predict_proba([get_sim(r, n2, str(li[0]))])[0][1]

        with open(out, 'a') as outf:
            print(r, n1, n2, max(t1, t2), file=outf)

# %%
from clf import *
from util import localfile

c = classify()

file = 'data/clf/second_msr_pairs_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap_X.json'
ys = localfile.get_file(file)
rets = c.predict_proba(ys)

tot = len(rets)
num = len(list(filter(lambda x: x[1] >= 0.55, rets)))

print(1.0 * num / tot)

# %%
threshold = 0.625

repo_num = {}
repo_tot = {}

with open('detection/result_on_topk_new_thres.txt') as f:
    for t in f.readlines():
        r, n1, n2, v = t.strip().split(' ')
        v = float(v)
                
        if r not in repo_num:
            repo_num[r] = 0
            repo_tot[r] = 0
        
        repo_tot[r] += 1
        if v >= threshold:
            repo_num[r] += 1
    
for r in repo_num:
    print(r, ':', 1.0 * repo_num[r] / repo_tot[r])
# Out:
# JuliaLang/julia : 0.0
# angular/angular.js : 0.1111111111111111
# ansible/ansible : 0.04081632653061224
# ceph/ceph : 0.3263157894736842
# cocos2d/cocos2d-x : 0.10909090909090909
# django/django : 0.17647058823529413
# docker/docker : 0.0847457627118644
# dotnet/corefx : 0.0
# elastic/elasticsearch : 0.14285714285714285
# emberjs/ember.js : 0.06976744186046512
# facebook/react : 0.02857142857142857
# hashicorp/terraform : 0.1875
# joomla/joomla-cms : 0.10852713178294573
# rails/rails : 0.10204081632653061
