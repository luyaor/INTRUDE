# %%
import os
# way = 'pre'
# file = 'detection/result_on_topk_%s_tmp.txt' % way

file = 'detection/result_on_topk_pre_v3.txt'

cnt_num = 0
top_acc = [0 for i in range(30)]

last_run = {}
if os.path.exists(file):
    with open(file) as f:
        for t in f.readlines():
            ps = t.replace(',','').replace('[','').replace(']','').split()
            
            
            r, n1, n2 = ps[0], ps[1], ps[2]
            li = [int(x) for x in ps[3:]]
            
            '''
            if r != 'angular/angular.js':
            # if r != 'rails/rails':
            # if r != 'elastic/elasticsearch':
                continue
            '''
            
            cnt_num += 1
            for i in range(30):
                if int(n1) in li[:i+1]:
                    top_acc[i] += 1
            
            # print('now=', r, cnt_num, 'top1 acc =', 1.0 * top_acc[0] / cnt_num)
            
            if cnt_num == 247:
                break
            '''
            if (r, n1, n2) == ('angular/angular.js', '5746', '9827'):
                break
            '''

print(cnt_num)
for i in range(20):
    t = 1.0 * top_acc[i] / cnt_num
    top_acc[i] = t
    print('top%d acc \t %.4f' % (i+1, t))
# Out:
# 247
# top1 acc 	 0.2874
# top2 acc 	 0.3684
# top3 acc 	 0.4089
# top4 acc 	 0.4170
# top5 acc 	 0.4534
# top6 acc 	 0.4737
# top7 acc 	 0.4980
# top8 acc 	 0.5101
# top9 acc 	 0.5101
# top10 acc 	 0.5182
# top11 acc 	 0.5304
# top12 acc 	 0.5385
# top13 acc 	 0.5425
# top14 acc 	 0.5466
# top15 acc 	 0.5506
# top16 acc 	 0.5587
# top17 acc 	 0.5668
# top18 acc 	 0.5789
# top19 acc 	 0.5870
# top20 acc 	 0.5992

# %%
from git import *

r = 'elastic/elasticsearch'
t = open('ok.txt', 'w')
with open('evaluation/%s_select.txt' % r.replace('/', '_')) as f:
    for n in f.readlines():
        p = get_pull(r, n.strip())
        if not check_large(p):
            print(n.strip(), file=t)
t.close()

# %%
from git import *
from comp import *

def cp(p1, p2):
    if set(p2['title'].split()) & set(p1['title'].split()):
        return True
    
    if set([x['name'] for x in fetch_pr_info(p1)]) & set([x['name'] for x in fetch_pr_info(p2)]):
        return True
    
    if check_pattern(p1, p2) == 1:
        return True

    return False

r = 'laravel/framework'

pulls = get_repo_info(r, 'pull')

p = get_pull(r, '22057')

num, tot = 0, 0
for p2 in pulls:
    tot += 1
    if cp(p, p2):
        num += 1
    if tot % 100 == 0:
        print(1.0 * num / tot)

print(1.0 * num / len(pulls))
# Out:
# 0.14
# 0.105
# 0.11666666666666667
# 0.1225
# 0.128
# 0.12166666666666667
# 0.11571428571428571
# 0.115
# 0.11333333333333333
# 0.11
# 0.10272727272727272
# 0.09916666666666667
# 0.09384615384615384
# 0.09571428571428571
# 0.09333333333333334
# 0.093125
# 0.09176470588235294
# 0.09055555555555556
# 0.09105263157894737
# 0.09
# 0.09
# 0.08681818181818182
# 0.08565217391304347
# 0.08541666666666667
# 0.0844
# 0.08346153846153846
# 0.0837037037037037
# 0.0825
# 0.08206896551724138
# 0.08
# 0.08
# 0.080625
# 0.0803030303030303
# 0.08
# 0.07914285714285714
# 0.07916666666666666
# 0.07891891891891892
# 0.08052631578947368
# 0.08076923076923077
# 0.08175
# 0.08195121951219513
# 0.08190476190476191
# 0.08232558139534883
# 0.08181818181818182
# 0.08066666666666666
# 0.08
# 0.07893617021276596
# 0.07833333333333334
# 0.07816326530612244
# 0.0786
# 0.07862745098039216
# 0.07865384615384616
# 0.07792452830188679
# 0.07907407407407407
# 0.07927272727272727
# 0.07821428571428571
# 0.07789473684210527
# 0.07879310344827586
# 0.07830508474576271
# 0.07883333333333334
# 0.07852459016393443
# 0.07806451612903226
# 0.07809523809523809
# 0.07796875
# 0.07784615384615384
# 0.07696969696969697
# 0.07746268656716418
# 0.07764705882352942
# 0.07768115942028986
# 0.07742857142857143
# 0.0776056338028169
# 0.07736111111111112
# 0.07780821917808219
# 0.0777027027027027
# 0.0776
# 0.07776315789473684
# 0.0787012987012987
# 0.07833333333333334
# 0.0779746835443038
# 0.077625
# 0.07728395061728395
# 0.0773170731707317
# 0.07698795180722892
# 0.0769047619047619
# 0.07682352941176471
# 0.0763953488372093
# 0.07574712643678161
# 0.07556818181818181
# 0.07550561797752808
# 0.0758888888888889
# 0.0754945054945055
# 0.07532608695652174
# 0.07526881720430108
# 0.075
# 0.07463157894736842
# 0.07447916666666667
# 0.0745360824742268
# 0.07397959183673469
# 0.07353535353535354
# 0.0733
# 0.07326732673267326
# 0.07313725490196078
# 0.07339805825242718
# 0.07278846153846154
# 0.07295238095238095
# 0.07254716981132076
# 0.07224299065420561
# 0.07194444444444445
# 0.07146788990825688
# 0.071
# 0.07063063063063063
# 0.07044642857142858
# 0.07061946902654867
# 0.07008771929824562
# 0.07060869565217391
# 0.07008620689655172
# 0.07059829059829059
# 0.07033898305084746
# 0.06983193277310924
# 0.06983333333333333
# 0.06950413223140496
# 0.06926229508196721
# 0.0691869918699187
# 0.06911290322580645
# 0.07008
# 0.07
# 0.06968503937007874
# 0.06984375
# 0.0696124031007752
# 0.06976923076923076
# 0.06992366412213741
# 0.06992424242424243
# 0.06992481203007518
# 0.06985074626865671
# 0.06977777777777777
# 0.06977941176470588
# 0.06963503649635036
# 0.06976069615663524

# %%
from git import *
from comp import *

def cp(p1, p2):
    if set(p2['title'].split()) & set(p1['title'].split()):
        return True
    
    if set([x['name'] for x in fetch_pr_info(p1)]) & set([x['name'] for x in fetch_pr_info(p2)]):
        return True
    
    if check_pattern(p1, p2) == 1:
        return True

    return False
    
num, tot = 0, 0
file = 'data/clf/msr_positive_pairs.txt'
with open(file) as f:
    for t in f.readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        tot += 1
        if cp(p1, p2):
            num += 1
        else:
            print(r, n1, n2)
        
        if tot % 100 == 0:
            print(1.0 * num / tot)

print(1.0 * num / tot)
# Out:
# angular/angular.js 9481 9478
# mozilla-b2g/gaia 2459 2420
# angular/angular.js 3699 3697
# ansible/ansible 15533 14368
# ansible/ansible 24798 23001
# ceph/ceph 8260 7289
# ceph/ceph 5208 5205
# ceph/ceph 10438 10427
# ceph/ceph 13378 13367
# ceph/ceph 9006 8853
# docker/docker 30290 29121
# docker/docker 32237 31744
# dotnet/corefx 3267 3264
# dotnet/corefx 10460 10450
# dotnet/corefx 419 406
# dotnet/corefx 16069 9537
# 0.84
# elastic/elasticsearch 13643 8742
# elastic/elasticsearch 20545 20407
# emberjs/ember.js 11516 11509
# emberjs/ember.js 1070 1066
# joomla/joomla-cms 1140 1122
# joomla/joomla-cms 5293 3602
# finish write /DATA/luyao/pr_data/joomla/joomla-cms/3788/parse_diff.json to file....
# joomla/joomla-cms 7832 5368
# JuliaLang/julia 5706 5565
# JuliaLang/julia 13084 11547
# 0.875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-31a1b86a87b1> in <module>()
#      20         r, n1, n2 = t.split()
#      21         p1 = get_pull(r, n1)
# ---> 22         p2 = get_pull(r, n2)
#      23
#      24         tot += 1
#
# ~/PR_get/INTRUDE/git.py in get_pull(repo, num, renew)
#     200 def get_pull(repo, num, renew=False):
#     201     save_path = LOCAL_DATA_PATH + '/pr_data/%s/%s/api.json' % (repo, num)
# --> 202     if os.path.exists(save_path) and (not renew):
#     203         try:
#     204             return localfile.get_file(save_path)
#
# ~/anaconda3/envs/p3/lib/python3.6/genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#      21         return False
#
# KeyboardInterrupt:

# %%
from git import *

r = 'laravel/framework'

pulls = get_repo_info(r, 'pull')

def f():
    cnt = 0
    for p in pulls:
        t = fetch_pr_info(p)
        cnt += 1
        if cnt == 100:
            break

# %timeit f()
# Out:
# 73.9 ms ± 6.01 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
