# %%
import os
way = 'pre'
file = 'detection/result_on_topk_%s_tmp.txt' % way

cnt_num = 0
top_acc = [0 for i in range(30)]

last_run = {}
if os.path.exists(file):
    with open(file) as f:
        for t in f.readlines():
            ps = t.replace(',','').replace('[','').replace(']','').split()
            
            
            r, n1, n2 = ps[0], ps[1], ps[2]
            li = [int(x) for x in ps[3:]]
            
            '''
            if r != 'angular/angular.js':
            # if r != 'rails/rails':
            # if r != 'elastic/elasticsearch':
                continue
            '''
            
            cnt_num += 1
            for i in range(30):
                if int(n1) in li[:i+1]:
                    top_acc[i] += 1
            
            # print('now=', r, cnt_num, 'top1 acc =', 1.0 * top_acc[0] / cnt_num)
            
            if cnt_num == 223:
                break
            '''
            if (r, n1, n2) == ('angular/angular.js', '5746', '9827'):
                break
            '''

print(cnt_num)
for i in range(20):
    t = 1.0 * top_acc[i] / cnt_num
    top_acc[i] = t
    print('top%d acc \t %.4f' % (i+1, t))
# Out:
# 223
# top1 acc 	 0.2377
# top2 acc 	 0.3408
# top3 acc 	 0.3812
# top4 acc 	 0.3946
# top5 acc 	 0.4305
# top6 acc 	 0.4574
# top7 acc 	 0.4753
# top8 acc 	 0.4888
# top9 acc 	 0.4933
# top10 acc 	 0.5022
# top11 acc 	 0.5112
# top12 acc 	 0.5291
# top13 acc 	 0.5336
# top14 acc 	 0.5381
# top15 acc 	 0.5426
# top16 acc 	 0.5471
# top17 acc 	 0.5561
# top18 acc 	 0.5695
# top19 acc 	 0.5785
# top20 acc 	 0.5919

# %%
from git import *

with open('evaluation/facebook_react_select.txt') as f:
    for n in f.readlines():
        p = get_pull('facebook/react', n.strip())
        if not check_large(p):
            print(n.strip())
# Out:
# 1702
# 3969
# 11868
# 12488
# 12621
# 4344
# 11638
# 5028
# 8522
# 10255
# 10115
# 11489
# 2084
# 1664
# 7870
# 8464
# 10787
# 6287
# 7532
# 11749
# 9140
# 5009
# 12780
# 9050
# 1036
# 13231
# 8996
# 2311
# 9649
# 8121
# 10697
# 10884
# 10077
# 8048
# 6123
# 9334
# 10988
# 7126
# 8462
# 4943
# 7571
# 10293
# 2740
# 3603
# 10280
# 7217
# 10825
# 7329
# 5787
# 6808
# 8764
# 6273
# 6432
# 7090
# 4132
# 6716
# 7955
# 5698
# 12914
# 12037
# 338
# 8463
# 11127
# 2066
# 6311
# 3175
# 2083
# 12267
# 10179
# 10716
# 8911
# 11813
# 3427
# 5736
# 7129
# 10570
# 8037
# 9912
# 3815
# 8003
# 109
# 13160
# 7748
# 12778
# 7361
# 3580
# 1601
# 7564
# 5931
# 5997
# 13172
# 11534
# 8590
# 4098
# 9555
# 9225
# 8345
# 8195
# 6945
# 6161
# 7619
# 9919
# 9969
# 10856
# 9534
# 9813
# 12607
# 1965
# 10079
# 11837
# 7112
# 9098
# 10236
# 10151
# 11350
# 686
# 9978
# 3182
# 6020
# 8385
# 4659
# 11782
# 9752
# 12609
# 7966
# 12770
# 13072
# 6195
# 10027
# 9382
# 11141
# 1198
# 5556
# 2038
# 11611
# 6210
# 11424
# 5056
# 9672
# 7085
# 9113
# 8918
# 6462
# 1570
# 4363
# 10655
# 8036
# 412
# 6208
# 1550
# 3861
# 10101
# 1882
# 11325
# 8620
# 11550
# 3239
# 12080
# 12801
# 3144
# 2000
# 10473
# 6095
# 3233
# 6765
# 1267
# 2772
# 1576
# 3922
# 336
# 3554
# 3641
# 3011
# 5749
# 1106
# 1528
# 716
# 934
# 700
# 2562
# 1972
# 967
# 594
# 572
# 287
# 1479
# 6403
# 420
# 476
# 56
# 241
# 202
# 297
# 91
# 30
# 2
