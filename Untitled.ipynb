# %%
import os
way = 'new'
file = 'detection/result_on_topk_%s_tmp.txt' % way

# file = 'detection/result_on_topk_pre_v3.txt'

cnt_num = 0
top_acc = [0 for i in range(30)]

last_run = {}
if os.path.exists(file):
    with open(file) as f:
        for t in f.readlines():
            ps = t.replace(',','').replace('[','').replace(']','').split()
            
            
            r, n1, n2 = ps[0], ps[1], ps[2]
            li = [int(x) for x in ps[3:]]
            
            '''
            if r != 'angular/angular.js':
            # if r != 'rails/rails':
            # if r != 'elastic/elasticsearch':
                continue
            '''
            
            cnt_num += 1
            for i in range(30):
                if int(n1) in li[:i+1]:
                    top_acc[i] += 1
            
            # print('now=', r, cnt_num, 'top1 acc =', 1.0 * top_acc[0] / cnt_num)
            
            '''
            if (r, n1, n2) == ('angular/angular.js', '5746', '9827'):
                break
            '''

print(cnt_num)
for i in range(30):
    t = 1.0 * top_acc[i] / cnt_num
    top_acc[i] = t
    print('top%d acc \t %.4f' % (i+1, t))

# %%
from git import *

r = 'elastic/elasticsearch'
t = open('ok.txt', 'w')
with open('evaluation/%s_select.txt' % r.replace('/', '_')) as f:
    for n in f.readlines():
        p = get_pull(r, n.strip())
        if not check_large(p):
            print(n.strip(), file=t)
t.close()

# %%
from git import *
from comp import *

def cp(p1, p2):
    if set(p2['title'].split()) & set(p1['title'].split()):
        return True
    
    if set([x['name'] for x in fetch_pr_info(p1)]) & set([x['name'] for x in fetch_pr_info(p2)]):
        return True
    
    if check_pattern(p1, p2) == 1:
        return True

    return False

r = 'laravel/framework'

pulls = get_repo_info(r, 'pull')

p = get_pull(r, '22057')

num, tot = 0, 0
for p2 in pulls:
    tot += 1
    if cp(p, p2):
        num += 1
    if tot % 100 == 0:
        print(1.0 * num / tot)

print(1.0 * num / len(pulls))

# %%
from git import *
from comp import *

def cp(p1, p2):
    if set(p2['title'].split()) & set(p1['title'].split()):
        return True
    
    if set([x['name'] for x in fetch_pr_info(p1)]) & set([x['name'] for x in fetch_pr_info(p2)]):
        return True
    
    if check_pattern(p1, p2) == 1:
        return True

    return False
    
num, tot = 0, 0
file = 'data/clf/msr_positive_pairs.txt'
with open(file) as f:
    for t in f.readlines():
        r, n1, n2 = t.split()
        p1 = get_pull(r, n1)
        p2 = get_pull(r, n2)
        
        tot += 1
        if cp(p1, p2):
            num += 1
        else:
            print(r, n1, n2)
        
        if tot % 100 == 0:
            print(1.0 * num / tot)

print(1.0 * num / tot)

# %%
from git import *

r = 'laravel/framework'

pulls = get_repo_info(r, 'pull')

def f():
    cnt = 0
    for p in pulls:
        t = fetch_pr_info(p)
        cnt += 1
        if cnt == 100:
            break

# %timeit f()

# %%
from git import *
from comp import *
from clf import *

c=classify()
lastr = None

file = 'detection/result_on_topk_new.txt'
out = 'detection/result_on_topk_new_thres.txt'

with open(file) as f:
    for t in f.readlines():
        ps = t.replace(',','').replace('[','').replace(']','').split()            
        r, n1, n2 = ps[0], ps[1], ps[2]
        li = [int(x) for x in ps[3:]]

        if lastr != r:
            init_model_with_repo(r)
            lastr = r

        t1 = c.predict_proba([get_sim(r, n2, n1)])[0][1]
        t2 = c.predict_proba([get_sim(r, n2, str(li[0]))])[0][1]

        with open(out, 'a') as outf:
            print(r, n1, n2, max(t1, t2), file=outf)

# %%
from clf import *
from util import localfile

c = classify()

# file = 'data/clf/second_msr_pairs_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap_X.json'
file = 'data/clf/second_nondup_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap_X.json'

ys = localfile.get_file(file)
rets = c.predict_proba(ys)

tot = len(rets)
num = len(list(filter(lambda x: x[1] >= 0.45, rets)))

print(1.0 * num / tot)
# Out:
# Data Loading.........
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_nondup.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/first_nondup_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_nondup.txt
# warning: feature vectore already exists! /home/luyao/PR_get/INTRUDE/data/clf/second_nondup_feature_vector_ok_text_lsi_code_tfidf_ori_and_overlap
# --------------------------
# Model: training_set 50618 testing_set 50737 feature_length= 9
# ------ model:  boost ------
# [0.22  0.42  0.105 0.005 0.04  0.055 0.045 0.045 0.065]
# Mean Accuracy: 0.9942645406705166
# Average precision score: 0.9191
# F1 score: 0.8643
# threshold acc = 0.9942645406705166
# threshold re-call = 0.8067885117493473
# threshold precision = 0.9307228915662651
# 0.016395095587642173

# %%
threshold = 0.60

repo_num = {}
repo_tot = {}

with open('detection/result_on_topk_new_thres.txt') as f:
    for t in f.readlines():
        r, n1, n2, v = t.strip().split(' ')
        v = float(v)
                
        if r not in repo_num:
            repo_num[r] = 0
            repo_tot[r] = 0
        
        repo_tot[r] += 1
        if v >= threshold:
            repo_num[r] += 1
    
for r in repo_num:
    print(r, ':', 1.0 * repo_num[r] / repo_tot[r])
# Out:
# JuliaLang/julia : 0.030303030303030304
# angular/angular.js : 0.2037037037037037
# ansible/ansible : 0.1326530612244898
# ceph/ceph : 0.4105263157894737
# cocos2d/cocos2d-x : 0.21818181818181817
# django/django : 0.39215686274509803
# docker/docker : 0.1864406779661017
# dotnet/corefx : 0.19047619047619047
# elastic/elasticsearch : 0.1836734693877551
# emberjs/ember.js : 0.16279069767441862
# facebook/react : 0.08571428571428572
# hashicorp/terraform : 0.3333333333333333
# joomla/joomla-cms : 0.23255813953488372
# rails/rails : 0.24489795918367346
