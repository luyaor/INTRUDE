# %%
import detect
detect.filter_same_author_and_already_mentioned = False
r = 'joomla/joomla-cms'
n1 = '15618'
n2 = '15633'

li = [int(x[0]) for x in detect.get_topK(r, n2, 30, True)]
print(r, n1, n2, li)
# Out:
# text_sim_type= lsi
# code_sim_type= tfidf
# extract_sim_type= ori_and_overlap
# Data Type: ok_text_lsi_code_tfidf_ori_and_overlap
# Data Loading.........
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs.txt
# ...
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs.txt
# ...
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_nondup.txt
# ...
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_nondup.txt
# ...
# --------------------------
# Model: training_set 50618 testing_set 50737 feature_length= 9
# ------ model:  boost ------
# [0.22  0.42  0.105 0.005 0.055 0.04  0.04  0.05  0.065]
# Mean Accuracy: 0.9942645406705166
# Average precision score: 0.9191
# F1 score: 0.8643
# threshold acc = 0.9942645406705166
# threshold re-call = 0.8067885117493473
# threshold precision = 0.9307228915662651
# init nlp model with joomla/joomla-cms data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# ...

# %%
import detect
detect.filter_same_author_and_already_mentioned = False
r = 'joomla/joomla-cms'
n1 = '15618'
n2 = '15633'

li = [int(x[0]) for x in detect.get_topK(r, n2, 30, True, 'pre')]
print(r, n1, n2, li)
# Out:
# progress =  0.20037211965078003
# progress =  0.207528266781165
# progress =  0.21468441391155002
# progress =  0.22184056104193503
# progress =  0.22899670817232
# progress =  0.23615285530270502
# progress =  0.24330900243309003
# progress =  0.25046514956347504
# progress =  0.25762129669386
# progress =  0.264777443824245
# progress =  0.27193359095463004
# progress =  0.279089738085015
# progress =  0.2862458852154
# progress =  0.29340203234578505
# progress =  0.30055817947617003
# progress =  0.307714326606555
# progress =  0.31487047373694005
# progress =  0.32202662086732503
# progress =  0.32918276799771
# progress =  0.33633891512809505
# progress =  0.34349506225848003
# progress =  0.350651209388865
# progress =  0.35780735651925005
# progress =  0.36496350364963503
# progress =  0.37211965078002
# progress =  0.37927579791040505
# progress =  0.38643194504079004
# progress =  0.393588092171175
# progress =  0.40074423930156006
# progress =  0.40790038643194504
# ...

# %%
import detect
detect.filter_same_author_and_already_mentioned = False
r = 'cocos2d/cocos2d-x'
n1 = '11441'
n2 = '11583'

li = [int(x[0]) for x in detect.get_topK(r, n2, 30, True, 'pre')]
print(r, n1, n2, li)
# Out:
# init nlp model with cocos2d/cocos2d-x data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# progress =  0.3257328990228013
# progress =  0.3325190010857763
# progress =  0.33930510314875134
# progress =  0.34609120521172637
# progress =  0.3528773072747014
# progress =  0.35966340933767643
# progress =  0.36644951140065146
# progress =  0.3732356134636265
# progress =  0.3800217155266015
# progress =  0.38680781758957655
# progress =  0.3935939196525516
# progress =  0.4003800217155266
# progress =  0.40716612377850164
# progress =  0.4139522258414767
# progress =  0.4207383279044517
# progress =  0.42752442996742673
# progress =  0.43431053203040176
# progress =  0.44109663409337674
# progress =  0.44788273615635177
# progress =  0.4546688382193268
# progress =  0.46145494028230183
# progress =  0.46824104234527686
# progress =  0.4750271444082519
# progress =  0.4818132464712269
# ...
