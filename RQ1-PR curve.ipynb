# %%
# recall data prep
from git import *
from comp import *
from detect import *
from clf import *
from val import *

# threshold = 0.60

repo_num = {}
repo_tot = {}

c = classify()
lastr = None

file = 'detection/result_on_topk_new_pok.txt'
fileout = 'detection/result_on_topk_new_pok_thres_tmp.txt'

with open(fileout, 'w') as f:
    pass

cnt = 0
with open(file) as f:
    for t in f.readlines():
        ps = t.replace(',','').replace('[','').replace(']','').split()            
        r, n1, n2 = ps[0], ps[1], ps[2]
        if n1 > n2:
            n1, n2 = n2, n1
        
        li = [int(x) for x in ps[3:]]

        if lastr != r:
            init_model_with_repo(r)
            lastr = r
            
        res = 0.0
        for x in li:
            x = str(x)
            if check_ok_new(get_pull(r, x), get_pull(r, n2)):
                res = c.predict_proba([get_sim(r, n2, x)])[0][1]
                break
        
        '''
        if res == 0:
            res = c.predict_proba([get_sim(r, n2, n1)])[0][1]
        '''
        
        cnt += 1
        if cnt % 100 == 0:
            print(cnt)
        with open(fileout,'a') as outf:
            print(r, n1, n2, res, file=outf)

print(cnt)
# Out:
# Data Loading.........
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_msr_pairs.txt
# ...
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_msr_pairs.txt
# ...
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/first_nondup.txt
# ...
# Model Data Input= /home/luyao/PR_get/INTRUDE/data/clf/second_nondup.txt
# ...
# --------------------------
# Model: training_set 50618 testing_set 50737 feature_length= 9
# ------ model:  boost ------
# [0.22  0.42  0.105 0.005 0.04  0.055 0.04  0.05  0.065]
# Mean Accuracy: 0.9942645406705166
# Average precision score: 0.9191
# F1 score: 0.8643
# threshold acc = 0.9942645406705166
# threshold re-call = 0.8067885117493473
# threshold precision = 0.9307228915662651
# init nlp model with JuliaLang/julia data!
# model already exists!
# init nlp model for text successfully!
# model already exists!
# init nlp model for code successfully!
# init nlp model with angular/angular.js data!
# model already exists!
# init nlp model for text successfully!
# ...
